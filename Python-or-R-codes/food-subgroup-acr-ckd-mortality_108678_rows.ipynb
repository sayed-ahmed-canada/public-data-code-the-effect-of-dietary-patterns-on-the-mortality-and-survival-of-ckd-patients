# %%
# PCA section, Correlation, Heatmaps, and then Bivariate plots can be seen to be important
# Might have to adjust/improve my conclusions from the plots in future work

# %%
# Target variable ESRD patients: Avg. Annual Mortality rates is given the most importance
# One another target variable is: ESRD patients: Total (or %) deaths for target year
# Other target variables: Dialysis patients: Total (or %) deaths for target year

# %%
# For plotting
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import numpy as np

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Is not using ratio with recommended amounts. Ratios as used with Food Groups did not show any difference with the actual amount taken. However, that might change with food subgroups.

# %%
# data exploration
import pandas as pd
df = pd.read_csv('./data-for-code/food_subgroup_intake_acr_and_mortality.csv')
df.head()
# Out:
#    participant_id  participant_age  gender                food_group_name  \
# 0           83747               46       1  Sugars, sweets, and beverages
# 1           83755               67       1  Sugars, sweets, and beverages
# 2           83803               27       1  Sugars, sweets, and beverages
# 3           83853               49       2  Sugars, sweets, and beverages
# 4           83894               60       1  Sugars, sweets, and beverages
#
#      food_subgroup_name  avg_food_weight_in_gms     acr  kidney_failed  \
# 0  Alcoholic beverages                   750.00   38.92            2.0
# 1  Alcoholic beverages                   210.00   19.88            2.0
# 2  Alcoholic beverages                   345.00    2.45            2.0
# 3  Alcoholic beverages                   435.00    4.55            2.0
# 4  Alcoholic beverages                   641.67  373.93            2.0
#
#    systolic_pressure  diastolic_pressure  \
# 0              144.0                94.0
# 1              132.0                84.0
# 2              120.0                72.0
# 3              122.0                86.0
# 4              166.0               100.0
#
#                             ...                            \
# 0                           ...
# 1                           ...
# 2                           ...
# 3                           ...
# 4                           ...
#
#    how_frequest_leak_nonphysical  how_much_leak_bothering  \
# 0                            NaN                      NaN
# 1                            NaN                      NaN
# 2                            NaN                      NaN
# 3                            NaN                      NaN
# 4                            NaN                      1.0
#
#    how_much_daily_activities_affected  count_night_time_urinate  age_from  \
# 0                                 1.0                       NaN        45
# 1                                 0.0                       NaN        65
# 2                                 NaN                       NaN        25
# 3                                 NaN                       NaN        45
# 4                                 3.0                       NaN        60
#
#    age_to  ESRD patients: Avg. Annual Mortality rates  \
# 0      49                                       5.980
# 1      69                                      15.475
# 2      29                                       2.845
# 3      49                                       5.980
# 4      64                                      12.035
#
#    Dialysis patients: Avg. Annual Mortality rates  \
# 0                                           8.735
# 1                                          19.285
# 2                                           4.680
# 3                                           8.735
# 4                                          15.550
#
#    ESRD patients: Total (or %) deaths for target year  \
# 0                                             3301.5
# 1                                            15064.0
# 2                                              354.0
# 3                                             3301.5
# 4                                            11710.5
#
#    Dialysis patients: Total (or %) deaths for target year
# 0                                             2893.0
# 1                                            13041.0
# 2                                              311.0
# 3                                             2893.0
# 4                                            10175.0
#
# [5 rows x 55 columns]

# %%
df.describe()
# Out:
#        participant_id  participant_age         gender  avg_food_weight_in_gms  \
# count   108768.000000    108768.000000  108768.000000           108768.000000
# mean     88765.315019        37.303315       1.519611              164.054298
# std       2867.698388        23.856184       0.499618              284.503168
# min      83732.000000         3.000000       1.000000                0.030000
# 25%      86281.000000        14.000000       1.000000               32.810000
# 50%      88814.000000        36.000000       2.000000               85.000000
# 75%      91234.000000        58.000000       2.000000              198.450000
# max      93702.000000        80.000000       2.000000             9600.000000
#
#                  acr  kidney_failed  systolic_pressure  diastolic_pressure  \
# count  105582.000000   72775.000000       93270.000000        93270.000000
# mean       43.876484       1.965538         120.931017           66.260663
# std       357.927124       0.321403          18.621494           14.103232
# min         0.220000       1.000000          72.000000            0.000000
# 25%         5.200000       2.000000         108.000000           58.000000
# 50%         8.180000       2.000000         118.000000           66.000000
# 75%        15.770000       2.000000         130.000000           76.000000
# max     21152.170000       9.000000         236.000000          120.000000
#
#              calorie        protein  \
# count  108768.000000  108768.000000
# mean      179.561415       7.305974
# std       212.899901      12.413807
# min         0.000000       0.000000
# 25%        43.000000       0.390000
# 50%       119.000000       2.590000
# 75%       237.000000       8.400000
# max      4100.000000     247.640000
#
#                                 ...                            \
# count                           ...
# mean                            ...
# std                             ...
# min                             ...
# 25%                             ...
# 50%                             ...
# 75%                             ...
# max                             ...
#
#        how_frequest_leak_nonphysical  how_much_leak_bothering  \
# count                    6965.000000             27354.000000
# mean                        2.377602                 1.498830
# std                         1.194407                 0.872035
# min                         1.000000                 1.000000
# 25%                         1.000000                 1.000000
# 50%                         2.000000                 1.000000
# 75%                         3.000000                 2.000000
# max                         9.000000                 9.000000
#
#        how_much_daily_activities_affected  count_night_time_urinate  \
# count                        69058.000000                       0.0
# mean                             1.290292                       NaN
# std                              1.199296                       NaN
# min                              0.000000                       NaN
# 25%                              0.000000                       NaN
# 50%                              1.000000                       NaN
# 75%                              2.000000                       NaN
# max                              9.000000                       NaN
#
#             age_from         age_to  \
# count  108768.000000  108768.000000
# mean       35.523683      39.267386
# std        23.987375      24.207423
# min         0.000000       4.000000
# 25%        14.000000      17.000000
# 50%        35.000000      39.000000
# 75%        55.000000      59.000000
# max        80.000000      84.000000
#
#        ESRD patients: Avg. Annual Mortality rates  \
# count                               108768.000000
# mean                                     7.518997
# std                                      8.988376
# min                                      0.505000
# 25%                                      0.925000
# 50%                                      4.140000
# 75%                                      9.675000
# max                                     37.590000
#
#        Dialysis patients: Avg. Annual Mortality rates  \
# count                                   108768.000000
# mean                                         9.875691
# std                                          9.288070
# min                                          1.115000
# 25%                                          4.065000
# 50%                                          6.460000
# 75%                                         12.955000
# max                                         38.800000
#
#        ESRD patients: Total (or %) deaths for target year  \
# count                                      108768.000000
# mean                                         4328.904531
# std                                          5510.584407
# min                                             8.000000
# 25%                                            12.500000
# 50%                                          1120.500000
# 75%                                          8585.500000
# max                                         15064.000000
#
#        Dialysis patients: Total (or %) deaths for target year
# count                                      108768.000000
# mean                                         3809.742493
# std                                          4842.176872
# min                                             3.500000
# 25%                                             8.000000
# 50%                                          1001.500000
# 75%                                          7515.000000
# max                                         13041.000000
#
# [8 rows x 50 columns]

# %%
#####

df_food_subgroup_only = df[ ['participant_id',  'food_subgroup_name', 'avg_food_weight_in_gms'] ]
df_food_subgroup_only.head()

df_food_subgroup_only_index = df_food_subgroup_only.set_index(['participant_id', 'food_subgroup_name'])
df_food_subgroup_only_index

df_food_subgroup_only_index_unstack = df_food_subgroup_only_index.unstack()
df_food_subgroup_only_index_unstack.head()
#####
# Out:
#                    avg_food_weight_in_gms          \
# food_subgroup_name   Alcoholic beverages     Beef
# participant_id
# 83732                                 NaN  113.33
# 83733                              1740.0     NaN
# 83734                                 NaN  113.40
# 83735                                 NaN     NaN
# 83736                                 NaN     NaN
#
#                                                           \
# food_subgroup_name Cakes, cookies, pies, pastries, bars
# participant_id
# 83732                                               48.0
# 83733                                              475.2
# 83734                                                NaN
# 83735                                                NaN
# 83736                                                NaN
#
#                                                                      \
# food_subgroup_name Cereals, not cooked or NS as to cooked  Cheeses
# participant_id
# 83732                                                  NaN      NaN
# 83733                                                  NaN      NaN
# 83734                                                  NaN      NaN
# 83735                                                  NaN      NaN
# 83736                                                  NaN      NaN
#
#                                            \
# food_subgroup_name Citrus fruits, juices
# participant_id
# 83732                               192.0
# 83733                                 NaN
# 83734                                 NaN
# 83735                                 NaN
# 83736                                96.0
#
#                                                                    \
# food_subgroup_name Crackers and salty snacks from grain products
# participant_id
# 83732                                                       32.05
# 83733                                                         NaN
# 83734                                                       28.00
# 83735                                                       21.00
# 83736                                                         NaN
#
#                                                                          \
# food_subgroup_name Creams and cream substitutes  Dark-green vegetables
# participant_id
# 83732                                       2.94                   76.5
# 83733                                        NaN                    NaN
# 83734                                       7.83                    NaN
# 83735                                      15.50                    NaN
# 83736                                        NaN                    NaN
#
#                                                    ...           \
# food_subgroup_name Deep-yellow vegetables          ...
# participant_id                                     ...
# 83732                                  NaN         ...
# 83733                                  NaN         ...
# 83734                                  NaN         ...
# 83735                                  NaN         ...
# 83736                                  NaN         ...
#
#                                                          \
# food_subgroup_name Sandwiches with meat, poultry, fish
# participant_id
# 83732                                             204.0
# 83733                                               NaN
# 83734                                             225.0
# 83735                                             242.0
# 83736                                               NaN
#
#                                              \
# food_subgroup_name Seeds and seed mixtures
# participant_id
# 83732                                   NaN
# 83733                                   NaN
# 83734                                   NaN
# 83735                                   NaN
# 83736                                   NaN
#
#                                                                            \
# food_subgroup_name Soups, broths, extracts from meat, poultry, fish base
# participant_id
# 83732                                                             NaN
# 83733                                                             NaN
# 83734                                                             NaN
# 83735                                                             NaN
# 83736                                                             NaN
#
#                                                                      \
# food_subgroup_name Sugars and sweets  Tomatoes and tomato mixtures
# participant_id
# 83732                            3.00                         20.00
# 83733                            7.29                        123.00
# 83734                             NaN                         23.99
# 83735                           10.67                           NaN
# 83736                           12.50                           NaN
#
#                                                                          \
# food_subgroup_name Vegetables and mixtures mostly vegetables baby food
# participant_id
# 83732                                                             NaN
# 83733                                                             NaN
# 83734                                                             NaN
# 83735                                                             NaN
# 83736                                                             NaN
#
#                                                                                \
# food_subgroup_name Vegetables with meat, poultry, fish  Water, noncarbonated
# participant_id
# 83732                                               NaN                 280.0
# 83733                                               NaN                 493.5
# 83734                                               NaN                 530.0
# 83735                                               NaN                 180.0
# 83736                                               NaN                   NaN
#
#                                                                         \
# food_subgroup_name White potatoes and Puerto Rican starchy vegetables
# participant_id
# 83732                                                           187.5
# 83733                                                             NaN
# 83734                                                           255.0
# 83735                                                            89.3
# 83736                                                             6.0
#
#
# food_subgroup_name Yeast breads, rolls
# participant_id
# 83732                              63.5
# 83733                              64.0
# 83734                              81.0
# 83735                               NaN
# 83736                               NaN
#
# [5 rows x 56 columns]

# %%
df_without_food_subgroups = df.drop(['food_subgroup_name',  'avg_food_weight_in_gms'], axis=1)
df_without_food_subgroups.head()

df_without_food_subgroups_one_entry = df_without_food_subgroups.groupby(['participant_id']).mean()
df_without_food_subgroups_one_entry.head()
# Out:
#                 participant_age  gender     acr  kidney_failed  \
# participant_id
# 83732                      62.0     1.0    6.10            2.0
# 83733                      53.0     1.0   12.82            2.0
# 83734                      78.0     1.0  150.00            1.0
# 83735                      56.0     2.0    5.69            2.0
# 83736                      42.0     2.0   15.11            2.0
#
#                 systolic_pressure  diastolic_pressure     calorie    protein  \
# participant_id
# 83732                       128.0                70.0  181.761905   8.924048
# 83733                       146.0                88.0  372.541667  12.121250
# 83734                       138.0                46.0  204.575000  10.043000
# 83735                       132.0                72.0  155.875000   8.677500
# 83736                       100.0                70.0  119.500000   3.234000
#
#                     sodium  carbohydrate  \
# participant_id
# 83732           395.420635     18.284286
# 83733           461.083333     37.678333
# 83734           396.916667     21.993500
# 83735           286.125000     17.962500
# 83736           195.700000     15.350000
#
#                                          ...                            \
# participant_id                           ...
# 83732                                    ...
# 83733                                    ...
# 83734                                    ...
# 83735                                    ...
# 83736                                    ...
#
#                 how_frequest_leak_nonphysical  how_much_leak_bothering  \
# participant_id
# 83732                                     NaN                      NaN
# 83733                                     NaN                      NaN
# 83734                                     NaN                      NaN
# 83735                                     NaN                      1.0
# 83736                                     NaN                      1.0
#
#                 how_much_daily_activities_affected  count_night_time_urinate  \
# participant_id
# 83732                                          0.0                       NaN
# 83733                                          0.0                       NaN
# 83734                                          1.0                       NaN
# 83735                                          1.0                       NaN
# 83736                                          1.0                       NaN
#
#                 age_from  age_to  ESRD patients: Avg. Annual Mortality rates  \
# participant_id
# 83732               60.0    64.0                                      12.035
# 83733               50.0    54.0                                       7.540
# 83734               75.0    79.0                                      25.350
# 83735               55.0    59.0                                       9.675
# 83736               40.0    44.0                                       4.515
#
#                 Dialysis patients: Avg. Annual Mortality rates  \
# participant_id
# 83732                                                   15.550
# 83733                                                   10.600
# 83734                                                   28.050
# 83735                                                   12.955
# 83736                                                    6.815
#
#                 ESRD patients: Total (or %) deaths for target year  \
# participant_id
# 83732                                                     11710.5
# 83733                                                      5466.0
# 83734                                                     14124.5
# 83735                                                      8585.5
# 83736                                                      1824.5
#
#                 Dialysis patients: Total (or %) deaths for target year
# participant_id
# 83732                                                     10175.0
# 83733                                                      4798.5
# 83734                                                     12452.5
# 83735                                                      7515.0
# 83736                                                      1611.0
#
# [5 rows x 48 columns]

# %%
merged = df_food_subgroup_only_index_unstack.merge(df_without_food_subgroups_one_entry,  how='inner', left_on='participant_id', right_on='participant_id', left_index=True)
merged.head()
merged.shape
merged.head()
# Out:
#                 (avg_food_weight_in_gms, Alcoholic beverages )  \
# participant_id
# 83732                                                      NaN
# 83733                                                   1740.0
# 83734                                                      NaN
# 83735                                                      NaN
# 83736                                                      NaN
#
#                 (avg_food_weight_in_gms, Beef)  \
# participant_id
# 83732                                   113.33
# 83733                                      NaN
# 83734                                   113.40
# 83735                                      NaN
# 83736                                      NaN
#
#                 (avg_food_weight_in_gms, Cakes, cookies, pies, pastries, bars )  \
# participant_id
# 83732                                                        48.0
# 83733                                                       475.2
# 83734                                                         NaN
# 83735                                                         NaN
# 83736                                                         NaN
#
#                 (avg_food_weight_in_gms, Cereals, not cooked or NS as to cooked )  \
# participant_id
# 83732                                                         NaN
# 83733                                                         NaN
# 83734                                                         NaN
# 83735                                                         NaN
# 83736                                                         NaN
#
#                 (avg_food_weight_in_gms, Cheeses )  \
# participant_id
# 83732                                          NaN
# 83733                                          NaN
# 83734                                          NaN
# 83735                                          NaN
# 83736                                          NaN
#
#                 (avg_food_weight_in_gms, Citrus fruits, juices )  \
# participant_id
# 83732                                                      192.0
# 83733                                                        NaN
# 83734                                                        NaN
# 83735                                                        NaN
# 83736                                                       96.0
#
#                 (avg_food_weight_in_gms, Crackers and salty snacks from grain products )  \
# participant_id
# 83732                                                       32.05
# 83733                                                         NaN
# 83734                                                       28.00
# 83735                                                       21.00
# 83736                                                         NaN
#
#                 (avg_food_weight_in_gms, Creams and cream substitutes )  \
# participant_id
# 83732                                                        2.94
# 83733                                                         NaN
# 83734                                                        7.83
# 83735                                                       15.50
# 83736                                                         NaN
#
#                 (avg_food_weight_in_gms, Dark-green vegetables )  \
# participant_id
# 83732                                                       76.5
# 83733                                                        NaN
# 83734                                                        NaN
# 83735                                                        NaN
# 83736                                                        NaN
#
#                 (avg_food_weight_in_gms, Deep-yellow vegetables )  \
# participant_id
# 83732                                                         NaN
# 83733                                                         NaN
# 83734                                                         NaN
# 83735                                                         NaN
# 83736                                                         NaN
#
#                                          ...                            \
# participant_id                           ...
# 83732                                    ...
# 83733                                    ...
# 83734                                    ...
# 83735                                    ...
# 83736                                    ...
#
#                 how_frequest_leak_nonphysical  how_much_leak_bothering  \
# participant_id
# 83732                                     NaN                      NaN
# 83733                                     NaN                      NaN
# 83734                                     NaN                      NaN
# 83735                                     NaN                      1.0
# 83736                                     NaN                      1.0
#
#                 how_much_daily_activities_affected  count_night_time_urinate  \
# participant_id
# 83732                                          0.0                       NaN
# 83733                                          0.0                       NaN
# 83734                                          1.0                       NaN
# 83735                                          1.0                       NaN
# 83736                                          1.0                       NaN
#
#                 age_from  age_to  ESRD patients: Avg. Annual Mortality rates  \
# participant_id
# 83732               60.0    64.0                                      12.035
# 83733               50.0    54.0                                       7.540
# 83734               75.0    79.0                                      25.350
# 83735               55.0    59.0                                       9.675
# 83736               40.0    44.0                                       4.515
#
#                 Dialysis patients: Avg. Annual Mortality rates  \
# participant_id
# 83732                                                   15.550
# 83733                                                   10.600
# 83734                                                   28.050
# 83735                                                   12.955
# 83736                                                    6.815
#
#                 ESRD patients: Total (or %) deaths for target year  \
# participant_id
# 83732                                                     11710.5
# 83733                                                      5466.0
# 83734                                                     14124.5
# 83735                                                      8585.5
# 83736                                                      1824.5
#
#                 Dialysis patients: Total (or %) deaths for target year
# participant_id
# 83732                                                     10175.0
# 83733                                                      4798.5
# 83734                                                     12452.5
# 83735                                                      7515.0
# 83736                                                      1611.0
#
# [5 rows x 104 columns]

# %%
# remove extra spaces in the column names
column_dict = {}
for aName in merged.columns:
    #print(aName)
    try:
        #if ( aName.index( 'avg_food_weight_in_gms' ) >= 0):
        if 'avg_food_weight_in_gms' in aName:
            #aName = 
            column_dict[aName] = aName[1] #aName.strip()
        else:
            column_dict[aName] = aName #.strip()
        
    except:
        print(aName)
        continue

# column_dict

# %%
merged = merged.rename(index=str, columns=column_dict)
merged.head()
# Out:
#                 Alcoholic beverages     Beef  \
# participant_id
# 83732                            NaN  113.33
# 83733                         1740.0     NaN
# 83734                            NaN  113.40
# 83735                            NaN     NaN
# 83736                            NaN     NaN
#
#                 Cakes, cookies, pies, pastries, bars   \
# participant_id
# 83732                                            48.0
# 83733                                           475.2
# 83734                                             NaN
# 83735                                             NaN
# 83736                                             NaN
#
#                 Cereals, not cooked or NS as to cooked   Cheeses   \
# participant_id
# 83732                                               NaN       NaN
# 83733                                               NaN       NaN
# 83734                                               NaN       NaN
# 83735                                               NaN       NaN
# 83736                                               NaN       NaN
#
#                 Citrus fruits, juices   \
# participant_id
# 83732                            192.0
# 83733                              NaN
# 83734                              NaN
# 83735                              NaN
# 83736                             96.0
#
#                 Crackers and salty snacks from grain products   \
# participant_id
# 83732                                                    32.05
# 83733                                                      NaN
# 83734                                                    28.00
# 83735                                                    21.00
# 83736                                                      NaN
#
#                 Creams and cream substitutes   Dark-green vegetables   \
# participant_id
# 83732                                    2.94                    76.5
# 83733                                     NaN                     NaN
# 83734                                    7.83                     NaN
# 83735                                   15.50                     NaN
# 83736                                     NaN                     NaN
#
#                 Deep-yellow vegetables   \
# participant_id
# 83732                               NaN
# 83733                               NaN
# 83734                               NaN
# 83735                               NaN
# 83736                               NaN
#
#                                          ...                            \
# participant_id                           ...
# 83732                                    ...
# 83733                                    ...
# 83734                                    ...
# 83735                                    ...
# 83736                                    ...
#
#                 how_frequest_leak_nonphysical  how_much_leak_bothering  \
# participant_id
# 83732                                     NaN                      NaN
# 83733                                     NaN                      NaN
# 83734                                     NaN                      NaN
# 83735                                     NaN                      1.0
# 83736                                     NaN                      1.0
#
#                 how_much_daily_activities_affected  count_night_time_urinate  \
# participant_id
# 83732                                          0.0                       NaN
# 83733                                          0.0                       NaN
# 83734                                          1.0                       NaN
# 83735                                          1.0                       NaN
# 83736                                          1.0                       NaN
#
#                 age_from  age_to  ESRD patients: Avg. Annual Mortality rates  \
# participant_id
# 83732               60.0    64.0                                      12.035
# 83733               50.0    54.0                                       7.540
# 83734               75.0    79.0                                      25.350
# 83735               55.0    59.0                                       9.675
# 83736               40.0    44.0                                       4.515
#
#                 Dialysis patients: Avg. Annual Mortality rates  \
# participant_id
# 83732                                                   15.550
# 83733                                                   10.600
# 83734                                                   28.050
# 83735                                                   12.955
# 83736                                                    6.815
#
#                 ESRD patients: Total (or %) deaths for target year  \
# participant_id
# 83732                                                     11710.5
# 83733                                                      5466.0
# 83734                                                     14124.5
# 83735                                                      8585.5
# 83736                                                      1824.5
#
#                 Dialysis patients: Total (or %) deaths for target year
# participant_id
# 83732                                                     10175.0
# 83733                                                      4798.5
# 83734                                                     12452.5
# 83735                                                      7515.0
# 83736                                                      1611.0
#
# [5 rows x 104 columns]

# %%
data_folder = './data-for-code/'

merged_f = merged.fillna(0)
merged_f.to_csv(data_folder + 'survival-food-subgroups-subgroup-names-on-columns-survival.csv')

# %%
merged_f.head()
df = merged_f
st = df

# %%
# deep, muted, pastel, bright, dark, and colorblind.
current_palette = sns.color_palette()
sns.palplot(current_palette)
sns.set_palette('colorblind')
current_palette = sns.color_palette()
sns.palplot(current_palette)

# %%
list(df.columns)
# Out:
# ['Alcoholic beverages ',
#  'Beef',
#  'Cakes, cookies, pies, pastries, bars ',
#  'Cereals, not cooked or NS as to cooked ',
#  'Cheeses ',
#  'Citrus fruits, juices ',
#  'Crackers and salty snacks from grain products ',
#  'Creams and cream substitutes ',
#  'Dark-green vegetables ',
#  'Deep-yellow vegetables ',
#  'Dried fruits ',
#  'Egg mixtures',
#  'Egg substitutes ',
#  'Eggs',
#  'Fats',
#  'Fish and shellfish ',
#  'Formulated nutrition beverages, energy drinks, sports drinks, functional beverages ',
#  'Frankfurters, sausages, lunchmeats, meat spreads',
#  'Frozen or shelf-stable plate meals with meat, poultry, fish as major ingredient ',
#  'Fruit juices and nectars excluding citrus ',
#  'Fruits and juices baby food ',
#  'Grain mixtures, frozen plate meals, soups ',
#  'Gravies from meat, poultry, fish base ',
#  'Lamb, veal, game, other carcass meat ',
#  'Legumes ',
#  'Meat substitutes, mainly cereal protein ',
#  'Meat, NS as to type ',
#  'Meat, poultry, fish in gravy or sauce or creamed ',
#  'Meat, poultry, fish with starch item (includes white potatoes) ',
#  'Meat, poultry, fish with starch item and vegetables ',
#  'Meat, poultry, fish with vegetables (excluding white potatoes) ',
#  'Milk desserts, sauces, gravies ',
#  'Milks and milk drinks ',
#  'Mixtures mostly vegetables without meat, poultry, fish ',
#  'Nonalcoholic beverages ',
#  'Nuts, nut butters, and nut mixtures ',
#  'Oils ',
#  'Organ meats and mixtures ',
#  'Other fruits ',
#  'Other vegetables ',
#  'Pancakes, waffles, French toast, other grain products ',
#  'Pastas, cooked cereals, rice ',
#  'Pork',
#  'Poultry',
#  'Quick breads ',
#  'Salad dressings ',
#  'Sandwiches with meat, poultry, fish ',
#  'Seeds and seed mixtures ',
#  'Soups, broths, extracts from meat, poultry, fish base ',
#  'Sugars and sweets ',
#  'Tomatoes and tomato mixtures ',
#  'Vegetables and mixtures mostly vegetables baby food ',
#  'Vegetables with meat, poultry, fish ',
#  'Water, noncarbonated ',
#  'White potatoes and Puerto Rican starchy vegetables ',
#  'Yeast breads, rolls ',
#  'participant_age',
#  'gender',
#  'acr',
#  'kidney_failed',
#  'systolic_pressure',
#  'diastolic_pressure',
#  'calorie',
#  'protein',
#  'sodium',
#  'carbohydrate',
#  'sugar',
#  'fibre',
#  'fat',
#  'saturated_fat',
#  'mono_fat',
#  'poly_fat',
#  'cholesterol',
#  'calcium',
#  'phosphorous',
#  'magnesium',
#  'potassium',
#  'alcohol',
#  'a_sample_food_code',
#  'food_group_id',
#  'albumin_urine_mu_g',
#  'albumin_urine_mg',
#  'creatinine_mu_mol',
#  'creatinine_mg',
#  'received_dialysis_in_12_months',
#  'kidney_stones',
#  'passed_kidney_stones_12_months',
#  'urinary_leakage_frequency',
#  'urine_lose_each_time',
#  'leak_during_activities',
#  'how_frequent_leak_occurs',
#  'urinated_before_reaching_toilet',
#  'how_frequent',
#  'leak_during_nonphysical_activities',
#  'how_frequest_leak_nonphysical',
#  'how_much_leak_bothering',
#  'how_much_daily_activities_affected',
#  'count_night_time_urinate',
#  'age_from',
#  'age_to',
#  'ESRD patients: Avg. Annual Mortality rates',
#  'Dialysis patients: Avg. Annual Mortality rates',
#  'ESRD patients: Total (or %) deaths for target year',
#  'Dialysis patients: Total (or %) deaths for target year']

# %%
df_actual_only = df[
    
    
    [

     'Alcoholic beverages ',
     'Beef',
     'Cakes, cookies, pies, pastries, bars ',
     'Cereals, not cooked or NS as to cooked ',
     'Cheeses ',
     'Citrus fruits, juices ',
     'Crackers and salty snacks from grain products ',
     'Creams and cream substitutes ',
     'Dark-green vegetables ',
     'Deep-yellow vegetables ',
     'Dried fruits ',
     'Egg mixtures',
     'Egg substitutes ',
     'Eggs',
     'Fats',
     'Fish and shellfish ',
     'Formulated nutrition beverages, energy drinks, sports drinks, functional beverages ',
     'Frankfurters, sausages, lunchmeats, meat spreads',
     'Frozen or shelf-stable plate meals with meat, poultry, fish as major ingredient ',
     'Fruit juices and nectars excluding citrus ',
     'Fruits and juices baby food ',
     'Grain mixtures, frozen plate meals, soups ',
     'Gravies from meat, poultry, fish base ',
     'Lamb, veal, game, other carcass meat ',
     'Legumes ',
     'Meat substitutes, mainly cereal protein ',
     'Meat, NS as to type ',
     'Meat, poultry, fish in gravy or sauce or creamed ',
     'Meat, poultry, fish with starch item (includes white potatoes) ',
     'Meat, poultry, fish with starch item and vegetables ',
     'Meat, poultry, fish with vegetables (excluding white potatoes) ',
     'Milk desserts, sauces, gravies ',
     'Milks and milk drinks ',
     'Mixtures mostly vegetables without meat, poultry, fish ',
     'Nonalcoholic beverages ',
     'Nuts, nut butters, and nut mixtures ',
     'Oils ',
     'Organ meats and mixtures ',
     'Other fruits ',
     'Other vegetables ',
     'Pancakes, waffles, French toast, other grain products ',
     'Pastas, cooked cereals, rice ',
     'Pork',
     'Poultry',
     'Quick breads ',
     'Salad dressings ',
     'Sandwiches with meat, poultry, fish ',
     'Seeds and seed mixtures ',
     'Soups, broths, extracts from meat, poultry, fish base ',
     'Sugars and sweets ',
     'Tomatoes and tomato mixtures ',
     'Vegetables and mixtures mostly vegetables baby food ',
     'Vegetables with meat, poultry, fish ',
     'Water, noncarbonated ',
     'White potatoes and Puerto Rican starchy vegetables ',
     'Yeast breads, rolls ',
     #'participant_age',
     #'gender',
     #'acr',
     #'kidney_failed',
     #'systolic_pressure',
     #'diastolic_pressure',
     #'calorie',
     #'protein',
     #'sodium',
     #'carbohydrate',
     #'sugar',
     #'fibre',
     #'fat',
     #'saturated_fat',
     #'mono_fat',
     #'poly_fat',
     #'cholesterol',
     #'calcium',
     #'phosphorous',
     #'magnesium',
     #'potassium',
     #'alcohol',
     #'a_sample_food_code',
     #'food_group_id',
     #'albumin_urine_mu_g',
     #'albumin_urine_mg',
     #'creatinine_mu_mol',
     #'creatinine_mg',
     #'received_dialysis_in_12_months',
     #'kidney_stones',
     #'passed_kidney_stones_12_months',
     #'urinary_leakage_frequency',
     #'urine_lose_each_time',
     #'leak_during_activities',
     #'how_frequent_leak_occurs',
     #'urinated_before_reaching_toilet',
     #'how_frequent',
     #'leak_during_nonphysical_activities',
     #'how_frequest_leak_nonphysical',
     #'how_much_leak_bothering',
     #'how_much_daily_activities_affected',
     #'count_night_time_urinate',
     #'age_from',
     #'age_to',
     'ESRD patients: Avg. Annual Mortality rates',
     'Dialysis patients: Avg. Annual Mortality rates',
     'ESRD patients: Total (or %) deaths for target year',
     'Dialysis patients: Total (or %) deaths for target year'

    ]    
    
    
]

# %%
df_actual_only.head()
# Out:
#                 Alcoholic beverages     Beef  \
# participant_id
# 83732                            0.0  113.33
# 83733                         1740.0    0.00
# 83734                            0.0  113.40
# 83735                            0.0    0.00
# 83736                            0.0    0.00
#
#                 Cakes, cookies, pies, pastries, bars   \
# participant_id
# 83732                                            48.0
# 83733                                           475.2
# 83734                                             0.0
# 83735                                             0.0
# 83736                                             0.0
#
#                 Cereals, not cooked or NS as to cooked   Cheeses   \
# participant_id
# 83732                                               0.0       0.0
# 83733                                               0.0       0.0
# 83734                                               0.0       0.0
# 83735                                               0.0       0.0
# 83736                                               0.0       0.0
#
#                 Citrus fruits, juices   \
# participant_id
# 83732                            192.0
# 83733                              0.0
# 83734                              0.0
# 83735                              0.0
# 83736                             96.0
#
#                 Crackers and salty snacks from grain products   \
# participant_id
# 83732                                                    32.05
# 83733                                                     0.00
# 83734                                                    28.00
# 83735                                                    21.00
# 83736                                                     0.00
#
#                 Creams and cream substitutes   Dark-green vegetables   \
# participant_id
# 83732                                    2.94                    76.5
# 83733                                    0.00                     0.0
# 83734                                    7.83                     0.0
# 83735                                   15.50                     0.0
# 83736                                    0.00                     0.0
#
#                 Deep-yellow vegetables   \
# participant_id
# 83732                               0.0
# 83733                               0.0
# 83734                               0.0
# 83735                               0.0
# 83736                               0.0
#
#                                          ...                            \
# participant_id                           ...
# 83732                                    ...
# 83733                                    ...
# 83734                                    ...
# 83735                                    ...
# 83736                                    ...
#
#                 Tomatoes and tomato mixtures   \
# participant_id
# 83732                                   20.00
# 83733                                  123.00
# 83734                                   23.99
# 83735                                    0.00
# 83736                                    0.00
#
#                 Vegetables and mixtures mostly vegetables baby food   \
# participant_id
# 83732                                                         0.0
# 83733                                                         0.0
# 83734                                                         0.0
# 83735                                                         0.0
# 83736                                                         0.0
#
#                 Vegetables with meat, poultry, fish   Water, noncarbonated   \
# participant_id
# 83732                                            0.0                  280.0
# 83733                                            0.0                  493.5
# 83734                                            0.0                  530.0
# 83735                                            0.0                  180.0
# 83736                                            0.0                    0.0
#
#                 White potatoes and Puerto Rican starchy vegetables   \
# participant_id
# 83732                                                       187.5
# 83733                                                         0.0
# 83734                                                       255.0
# 83735                                                        89.3
# 83736                                                         6.0
#
#                 Yeast breads, rolls   \
# participant_id
# 83732                           63.5
# 83733                           64.0
# 83734                           81.0
# 83735                            0.0
# 83736                            0.0
#
#                 ESRD patients: Avg. Annual Mortality rates  \
# participant_id
# 83732                                               12.035
# 83733                                                7.540
# 83734                                               25.350
# 83735                                                9.675
# 83736                                                4.515
#
#                 Dialysis patients: Avg. Annual Mortality rates  \
# participant_id
# 83732                                                   15.550
# 83733                                                   10.600
# 83734                                                   28.050
# 83735                                                   12.955
# 83736                                                    6.815
#
#                 ESRD patients: Total (or %) deaths for target year  \
# participant_id
# 83732                                                     11710.5
# 83733                                                      5466.0
# 83734                                                     14124.5
# 83735                                                      8585.5
# 83736                                                      1824.5
#
#                 Dialysis patients: Total (or %) deaths for target year
# participant_id
# 83732                                                     10175.0
# 83733                                                      4798.5
# 83734                                                     12452.5
# 83735                                                      7515.0
# 83736                                                      1611.0
#
# [5 rows x 60 columns]

# %%
# df_actual_only = df.drop(['Age-group: From USRDS', 'Age-group: To USRDS', 'Gender'], axis=1)
# df_actual_only.head()

# %%
####----
# steps followed from ref: https://python-for-multivariate-analysis.readthedocs.io/a_little_book_of_python_for_multivariate_analysis.html
import sklearn
from sklearn import preprocessing
standardisedX = sklearn.preprocessing.scale(df_actual_only)
standardisedX = pd.DataFrame(standardisedX, index=df_actual_only.index, columns=df_actual_only.columns)
standardisedX.apply(np.mean), '---\n', standardisedX.apply(np.std)
# Out:
# (Alcoholic beverages                                                                    3.822242e-16
#  Beef                                                                                   3.728486e-16
#  Cakes, cookies, pies, pastries, bars                                                   3.171157e-16
#  Cereals, not cooked or NS as to cooked                                                -5.310954e-17
#  Cheeses                                                                               -3.494617e-16
#  Citrus fruits, juices                                                                  1.694832e-17
#  Crackers and salty snacks from grain products                                         -5.346437e-16
#  Creams and cream substitutes                                                          -2.294874e-16
#  Dark-green vegetables                                                                  9.322008e-16
#  Deep-yellow vegetables                                                                -3.572561e-16
#  Dried fruits                                                                           1.785011e-15
#  Egg mixtures                                                                          -1.710554e-16
#  Egg substitutes                                                                        5.587824e-16
#  Eggs                                                                                   2.194338e-16
#  Fats                                                                                   2.337426e-16
#  Fish and shellfish                                                                     4.954679e-16
#  Formulated nutrition beverages, energy drinks, sports drinks, functional beverages     1.636126e-16
#  Frankfurters, sausages, lunchmeats, meat spreads                                      -2.137940e-16
#  Frozen or shelf-stable plate meals with meat, poultry, fish as major ingredient        8.329017e-16
#  Fruit juices and nectars excluding citrus                                             -2.310308e-16
#  Fruits and juices baby food                                                            7.944569e-16
#  Grain mixtures, frozen plate meals, soups                                             -1.032621e-16
#  Gravies from meat, poultry, fish base                                                 -7.515822e-16
#  Lamb, veal, game, other carcass meat                                                  -3.120690e-16
#  Legumes                                                                               -1.114363e-15
#  Meat substitutes, mainly cereal protein                                               -2.468094e-16
#  Meat, NS as to type                                                                   -4.655288e-16
#  Meat, poultry, fish in gravy or sauce or creamed                                      -2.315357e-16
#  Meat, poultry, fish with starch item (includes white potatoes)                        -1.230477e-15
#  Meat, poultry, fish with starch item and vegetables                                   -1.420485e-15
#  Meat, poultry, fish with vegetables (excluding white potatoes)                         8.249864e-17
#  Milk desserts, sauces, gravies                                                        -3.878713e-16
#  Milks and milk drinks                                                                 -1.797387e-16
#  Mixtures mostly vegetables without meat, poultry, fish                                -5.286361e-16
#  Nonalcoholic beverages                                                                -1.361743e-16
#  Nuts, nut butters, and nut mixtures                                                   -5.057090e-16
#  Oils                                                                                   7.307285e-16
#  Organ meats and mixtures                                                               9.580307e-17
#  Other fruits                                                                          -2.575567e-16
#  Other vegetables                                                                      -1.745208e-16
#  Pancakes, waffles, French toast, other grain products                                  3.021993e-16
#  Pastas, cooked cereals, rice                                                           1.654444e-16
#  Pork                                                                                  -2.938045e-16
#  Poultry                                                                               -8.730331e-16
#  Quick breads                                                                          -4.025334e-16
#  Salad dressings                                                                        6.786179e-16
#  Sandwiches with meat, poultry, fish                                                   -1.264994e-16
#  Seeds and seed mixtures                                                                6.264639e-16
#  Soups, broths, extracts from meat, poultry, fish base                                 -8.098556e-16
#  Sugars and sweets                                                                     -3.867101e-16
#  Tomatoes and tomato mixtures                                                          -3.029061e-17
#  Vegetables and mixtures mostly vegetables baby food                                   -1.521588e-15
#  Vegetables with meat, poultry, fish                                                   -7.836920e-16
#  Water, noncarbonated                                                                  -4.369421e-17
#  White potatoes and Puerto Rican starchy vegetables                                    -6.223422e-16
#  Yeast breads, rolls                                                                    4.276602e-16
#  ESRD patients: Avg. Annual Mortality rates                                             8.794374e-17
#  Dialysis patients: Avg. Annual Mortality rates                                         2.775918e-16
#  ESRD patients: Total (or %) deaths for target year                                     2.638456e-16
#  Dialysis patients: Total (or %) deaths for target year                                 1.581026e-16
#  dtype: float64,
#  '---\n',
#  Alcoholic beverages                                                                    1.0
#  Beef                                                                                   1.0
#  Cakes, cookies, pies, pastries, bars                                                   1.0
#  Cereals, not cooked or NS as to cooked                                                 1.0
#  Cheeses                                                                                1.0
#  Citrus fruits, juices                                                                  1.0
#  Crackers and salty snacks from grain products                                          1.0
#  Creams and cream substitutes                                                           1.0
#  Dark-green vegetables                                                                  1.0
#  Deep-yellow vegetables                                                                 1.0
#  Dried fruits                                                                           1.0
#  Egg mixtures                                                                           1.0
#  Egg substitutes                                                                        1.0
#  Eggs                                                                                   1.0
#  Fats                                                                                   1.0
#  Fish and shellfish                                                                     1.0
#  Formulated nutrition beverages, energy drinks, sports drinks, functional beverages     1.0
#  Frankfurters, sausages, lunchmeats, meat spreads                                       1.0
#  Frozen or shelf-stable plate meals with meat, poultry, fish as major ingredient        1.0
#  Fruit juices and nectars excluding citrus                                              1.0
#  Fruits and juices baby food                                                            1.0
#  Grain mixtures, frozen plate meals, soups                                              1.0
#  Gravies from meat, poultry, fish base                                                  1.0
#  Lamb, veal, game, other carcass meat                                                   1.0
#  Legumes                                                                                1.0
#  Meat substitutes, mainly cereal protein                                                1.0
#  Meat, NS as to type                                                                    1.0
#  Meat, poultry, fish in gravy or sauce or creamed                                       1.0
#  Meat, poultry, fish with starch item (includes white potatoes)                         1.0
#  Meat, poultry, fish with starch item and vegetables                                    1.0
#  Meat, poultry, fish with vegetables (excluding white potatoes)                         1.0
#  Milk desserts, sauces, gravies                                                         1.0
#  Milks and milk drinks                                                                  1.0
#  Mixtures mostly vegetables without meat, poultry, fish                                 1.0
#  Nonalcoholic beverages                                                                 1.0
#  Nuts, nut butters, and nut mixtures                                                    1.0
#  Oils                                                                                   1.0
#  Organ meats and mixtures                                                               1.0
#  Other fruits                                                                           1.0
#  Other vegetables                                                                       1.0
#  Pancakes, waffles, French toast, other grain products                                  1.0
#  Pastas, cooked cereals, rice                                                           1.0
#  Pork                                                                                   1.0
#  Poultry                                                                                1.0
#  Quick breads                                                                           1.0
#  Salad dressings                                                                        1.0
#  Sandwiches with meat, poultry, fish                                                    1.0
#  Seeds and seed mixtures                                                                1.0
#  Soups, broths, extracts from meat, poultry, fish base                                  1.0
#  Sugars and sweets                                                                      1.0
#  Tomatoes and tomato mixtures                                                           1.0
#  Vegetables and mixtures mostly vegetables baby food                                    1.0
#  Vegetables with meat, poultry, fish                                                    1.0
#  Water, noncarbonated                                                                   1.0
#  White potatoes and Puerto Rican starchy vegetables                                     1.0
#  Yeast breads, rolls                                                                    1.0
#  ESRD patients: Avg. Annual Mortality rates                                             1.0
#  Dialysis patients: Avg. Annual Mortality rates                                         1.0
#  ESRD patients: Total (or %) deaths for target year                                     1.0
#  Dialysis patients: Total (or %) deaths for target year                                 1.0
#  dtype: float64)

# %%
standardisedX.columns
# Out:
# Index(['Alcoholic beverages ', 'Beef', 'Cakes, cookies, pies, pastries, bars ',
#        'Cereals, not cooked or NS as to cooked ', 'Cheeses ',
#        'Citrus fruits, juices ',
#        'Crackers and salty snacks from grain products ',
#        'Creams and cream substitutes ', 'Dark-green vegetables ',
#        'Deep-yellow vegetables ', 'Dried fruits ', 'Egg mixtures',
#        'Egg substitutes ', 'Eggs', 'Fats', 'Fish and shellfish ',
#        'Formulated nutrition beverages, energy drinks, sports drinks, functional beverages ',
#        'Frankfurters, sausages, lunchmeats, meat spreads',
#        'Frozen or shelf-stable plate meals with meat, poultry, fish as major ingredient ',
#        'Fruit juices and nectars excluding citrus ',
#        'Fruits and juices baby food ',
#        'Grain mixtures, frozen plate meals, soups ',
#        'Gravies from meat, poultry, fish base ',
#        'Lamb, veal, game, other carcass meat ', 'Legumes ',
#        'Meat substitutes, mainly cereal protein ', 'Meat, NS as to type ',
#        'Meat, poultry, fish in gravy or sauce or creamed ',
#        'Meat, poultry, fish with starch item (includes white potatoes) ',
#        'Meat, poultry, fish with starch item and vegetables ',
#        'Meat, poultry, fish with vegetables (excluding white potatoes) ',
#        'Milk desserts, sauces, gravies ', 'Milks and milk drinks ',
#        'Mixtures mostly vegetables without meat, poultry, fish ',
#        'Nonalcoholic beverages ', 'Nuts, nut butters, and nut mixtures ',
#        'Oils ', 'Organ meats and mixtures ', 'Other fruits ',
#        'Other vegetables ',
#        'Pancakes, waffles, French toast, other grain products ',
#        'Pastas, cooked cereals, rice ', 'Pork', 'Poultry', 'Quick breads ',
#        'Salad dressings ', 'Sandwiches with meat, poultry, fish ',
#        'Seeds and seed mixtures ',
#        'Soups, broths, extracts from meat, poultry, fish base ',
#        'Sugars and sweets ', 'Tomatoes and tomato mixtures ',
#        'Vegetables and mixtures mostly vegetables baby food ',
#        'Vegetables with meat, poultry, fish ', 'Water, noncarbonated ',
#        'White potatoes and Puerto Rican starchy vegetables ',
#        'Yeast breads, rolls ', 'ESRD patients: Avg. Annual Mortality rates',
#        'Dialysis patients: Avg. Annual Mortality rates',
#        'ESRD patients: Total (or %) deaths for target year',
#        'Dialysis patients: Total (or %) deaths for target year'],
#       dtype='object')

# %%
y = abs(standardisedX['ESRD patients: Avg. Annual Mortality rates']) > 0.5 
standardisedX_with_target = standardisedX
standardisedX = standardisedX.drop(['ESRD patients: Avg. Annual Mortality rates', 'ESRD patients: Total (or %) deaths for target year',
                                   'Dialysis patients: Total (or %) deaths for target year', 'Dialysis patients: Avg. Annual Mortality rates'], axis=1)

# %%
from sklearn import decomposition
#pca = decomposition.PCA(n_components=2).fit(standardisedX)
pca = decomposition.PCA().fit(standardisedX)
pca
# Out:
# PCA(copy=True, iterated_power='auto', n_components=None, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)

# %%
#ref: https://python-for-multivariate-analysis.readthedocs.io/a_little_book_of_python_for_multivariate_analysis.html
def pca_summary(pca, standardised_data, out=True):
    names = ["PC"+str(i) for i in range(1, len(pca.explained_variance_ratio_)+1)]
    a = list(np.std(pca.transform(standardised_data), axis=0))
    b = list(pca.explained_variance_ratio_)
    c = [np.sum(pca.explained_variance_ratio_[:i]) for i in range(1, len(pca.explained_variance_ratio_)+1)]
    columns = pd.MultiIndex.from_tuples([("sdev", "Standard deviation"), ("varprop", "Proportion of Variance"), ("cumprop", "Cumulative Proportion")])
    summary = pd.DataFrame( list(zip(a, b, c)), index=names, columns=columns)
    if out:
        print("Importance of components:")
        display(summary)
    return summary

# %%
####----
summary = pca_summary(pca, standardisedX)
####----
# Out:
# Importance of components:
#                    sdev                varprop               cumprop
#      Standard deviation Proportion of Variance Cumulative Proportion
# PC1            1.361639               0.033108              0.033108
# PC2            1.276259               0.029086              0.062195
# PC3            1.241879               0.027540              0.089735
# PC4            1.137246               0.023095              0.112830
# PC5            1.126993               0.022681              0.135511
# PC6            1.111815               0.022074              0.157585
# PC7            1.099553               0.021590              0.179174
# PC8            1.085800               0.021053              0.200227
# PC9            1.062775               0.020169              0.220396
# PC10           1.059397               0.020041              0.240438
# PC11           1.055274               0.019886              0.260324
# PC12           1.049681               0.019676              0.279999
# PC13           1.045812               0.019531              0.299530
# PC14           1.041653               0.019376              0.318906
# PC15           1.036210               0.019174              0.338080
# PC16           1.028293               0.018882              0.356961
# PC17           1.024117               0.018729              0.375690
# PC18           1.018704               0.018531              0.394222
# PC19           1.017336               0.018482              0.412703
# PC20           1.013936               0.018358              0.431062
# PC21           1.010610               0.018238              0.449300
# PC22           1.006919               0.018105              0.467405
# PC23           1.002791               0.017957              0.485362
# PC24           1.000369               0.017870              0.503232
# PC25           0.997689               0.017775              0.521007
# PC26           0.994284               0.017654              0.538660
# PC27           0.988024               0.017432              0.556092
# PC28           0.984464               0.017307              0.573399
# PC29           0.983213               0.017263              0.590662
# PC30           0.976834               0.017039              0.607701
# PC31           0.976119               0.017014              0.624715
# PC32           0.975804               0.017003              0.641719
# PC33           0.967635               0.016720              0.658439
# PC34           0.966838               0.016692              0.675131
# PC35           0.957347               0.016366              0.691498
# PC36           0.954257               0.016261              0.707758
# PC37           0.953447               0.016233              0.723992
# PC38           0.948121               0.016052              0.740044
# PC39           0.945925               0.015978              0.756022
# PC40           0.940516               0.015796              0.771818
# PC41           0.937216               0.015685              0.787503
# PC42           0.929590               0.015431              0.802934
# PC43           0.927357               0.015357              0.818291
# PC44           0.924779               0.015272              0.833563
# PC45           0.920785               0.015140              0.848703
# PC46           0.916905               0.015013              0.863716
# PC47           0.911613               0.014840              0.878556
# PC48           0.906969               0.014689              0.893245
# PC49           0.899886               0.014461              0.907706
# PC50           0.895523               0.014321              0.922026
# PC51           0.890330               0.014155              0.936181
# PC52           0.875535               0.013689              0.949870
# PC53           0.867274               0.013432              0.963302
# PC54           0.851147               0.012937              0.976238
# PC55           0.820998               0.012036              0.988275
# PC56           0.810324               0.011725              1.000000

# %%
# First five component can define over 90%

# %%
# ref: https://python-for-multivariate-analysis.readthedocs.io/a_little_book_of_python_for_multivariate_analysis.html
np.sum( summary.sdev ** 2 )
plt.rcParams['figure.figsize'] = 8, 8

# %% [markdown]
# # Important Components

# %%
def screeplot(pca, standardised_values):
    y = np.std(pca.transform(standardised_values), axis=0)**2
    x = np.arange(len(y)) + 1
    plt.plot(x, y, "o-")
    plt.xticks(x, ["Comp."+str(i) for i in x], rotation=60)
    plt.ylabel("Variance")
    plt.title('PCA variance in Components')
    plt.savefig('../../progress_reports/to_submit/pca_univariate_bivariate/pca_components_variance' + '.png')            
    plt.show()

screeplot(pca, standardisedX)
#plt.savefig('../../progress_reports/to_submit/pca_univariate_bivariate/pca_components_variance' + '.png')

# %%
# comp 4 to 5 has the most slope change 
# first four are the most important

# %%
#summary.sdev**2
#pca.components_[0]
#np.sum(pca.components_[0]**2)

# %%
####----
# ref: https://python-for-multivariate-analysis.readthedocs.io/a_little_book_of_python_for_multivariate_analysis.html
# not my code, I am using this as (similar to) a library function with some adjustments
def calcpc(variables, loadings):
    # find the number of samples in the data set and the number of variables
    numsamples, numvariables = variables.shape
    # make a vector to store the component
    pc = np.zeros(numsamples)
    # calculate the value of the component for each sample
    for i in range(numsamples):
        valuei = 0
        for j in range(numvariables):
            valueij = variables.iloc[i, j]
            loadingj = loadings[j]
            valuei = valuei + (valueij * loadingj)
        pc[i] = valuei
    return pc

# %%
####----
calcpc(standardisedX, pca.components_[0])
pca.transform(standardisedX)[:, 0]
pca.transform(standardisedX)[:, 0]
pca.components_[1]
np.sum(pca.components_[1]**2)
#highest loadings for
# Out:
# 1.0000000000000007

# %%
# Define high and low mortality
# The code below is not used.
# y as defined earlier will rather be used

#import sklearn 
#from sklearn import preprocessing
#standardisedX_mortality = sklearn.preprocessing.scale(df_diff_ratio_mortality)
#standardisedX_mortality = pd.DataFrame(standardisedX_mortality, index=df_diff_ratio_mortality.index, columns=df_diff_ratio_mortality.columns)
#standardisedX_mortality.apply(np.mean), '---', standardisedX_mortality.apply(np.std)
#standardisedX_mortality

# %%
####----
# # ref: https://python-for-multivariate-analysis.readthedocs.io/a_little_book_of_python_for_multivariate_analysis.html
# not my code from the URL above, using this as a library function
def pca_scatter(pca, standardised_values, classifs):
    foo = pca.transform(standardised_values)
    bar = pd.DataFrame(list(zip(foo[:, 0], foo[:, 1], classifs)), columns=["PC1", "PC2", "Class"])
    #plt.savefig('../../progress_reports/to_submit/pca_univariate_bivariate/pca_components_separating_high_low_mortality' + '.png')            
    sns.lmplot("PC1", "PC2", bar, hue="Class", fit_reg=False)

pca_scatter(pca, standardisedX, y)

# y can be used as classes like High, low, neutral mortality

# plt.suptitle('Mortality class and Principle components, y can be used as classes like High, low, neutral mortality');
plt.title('Class separations True = High Mortality')
plt.savefig('./images/pca_components_separating_high_low_mortality' + '.png')            
standardisedX
# Out:
#                 Alcoholic beverages       Beef  \
# participant_id
# 83732                      -0.276774  1.746677
# 83733                       4.198610 -0.354007
# 83734                      -0.276774  1.747975
# 83735                      -0.276774 -0.354007
# 83736                      -0.276774 -0.354007
# 83737                      -0.276774 -0.354007
# 83738                      -0.276774 -0.354007
# 83739                      -0.276774 -0.354007
# 83741                      -0.276774 -0.354007
# 83742                      -0.276774 -0.354007
# 83744                      -0.276774 -0.354007
# 83745                      -0.276774 -0.354007
# 83747                       1.652271 -0.354007
# 83748                      -0.276774 -0.354007
# 83749                      -0.276774  2.798966
# 83750                      -0.276774 -0.354007
# 83751                      -0.276774 -0.354007
# 83752                      -0.276774 -0.354007
# 83753                      -0.276774 -0.354007
# 83754                      -0.276774 -0.354007
# 83755                       0.263359 -0.354007
# 83756                      -0.276774  0.813761
# 83757                      -0.276774  0.305689
# 83759                      -0.276774 -0.354007
# 83760                      -0.276774 -0.354007
# 83761                      -0.276774 -0.354007
# 83762                      -0.276774 -0.354007
# 83764                      -0.276774 -0.354007
# 83766                      -0.276774 -0.354007
# 83767                      -0.276774 -0.354007
# ...                              ...       ...
# 93660                      -0.276774 -0.354007
# 93661                      -0.276774 -0.043529
# 93663                       1.575109 -0.354007
# 93664                      -0.276774  4.148016
# 93665                      -0.083869 -0.354007
# 93667                      -0.276774  0.804493
# 93668                      -0.276774 -0.354007
# 93669                      -0.276774 -0.354007
# 93670                      -0.083869 -0.354007
# 93671                       0.047306  1.870312
# 93675                      -0.276774 -0.354007
# 93676                      -0.276774 -0.354007
# 93677                       0.568945 -0.354007
# 93680                      -0.276774 -0.354007
# 93682                      -0.276774 -0.354007
# 93683                      -0.276774 -0.354007
# 93684                      -0.276774  0.696984
# 93685                      -0.276774 -0.354007
# 93686                      -0.276774 -0.354007
# 93687                      -0.276774 -0.354007
# 93689                      -0.276774 -0.354007
# 93690                       0.957815 -0.354007
# 93691                      -0.276774  2.129816
# 93693                      -0.276774 -0.354007
# 93695                      -0.276774  0.887905
# 93696                      -0.276774 -0.354007
# 93697                      -0.083869  0.418202
# 93699                      -0.276774 -0.354007
# 93701                      -0.276774 -0.354007
# 93702                       0.494844 -0.354007
#
#                 Cakes, cookies, pies, pastries, bars   \
# participant_id
# 83732                                        0.285003
# 83733                                        8.476163
# 83734                                       -0.635352
# 83735                                       -0.635352
# 83736                                       -0.635352
# 83737                                       -0.635352
# 83738                                        0.400048
# 83739                                       -0.026575
# 83741                                        1.542055
# 83742                                        0.447983
# 83744                                       -0.635352
# 83745                                        0.649311
# 83747                                       -0.635352
# 83748                                        1.316376
# 83749                                       -0.635352
# 83750                                       -0.635352
# 83751                                       -0.635352
# 83752                                        9.366990
# 83753                                        0.400048
# 83754                                       -0.635352
# 83755                                        0.054915
# 83756                                        1.051966
# 83757                                        1.573500
# 83759                                        0.802703
# 83760                                        0.456995
# 83761                                       -0.635352
# 83762                                       -0.635352
# 83764                                        0.131611
# 83766                                       -0.635352
# 83767                                       -0.060130
# ...                                               ...
# 93660                                        0.176286
# 93661                                       -0.635352
# 93663                                       -0.635352
# 93664                                        0.320092
# 93665                                       -0.315720
# 93667                                        0.754768
# 93668                                       -0.635352
# 93669                                       -0.635352
# 93670                                        0.841051
# 93671                                       -0.635352
# 93675                                       -0.635352
# 93676                                        2.240758
# 93677                                        0.016566
# 93680                                       -0.213522
# 93682                                       -0.635352
# 93683                                        0.169959
# 93684                                        3.317765
# 93685                                       -0.635352
# 93686                                        0.169959
# 93687                                        0.630137
# 93689                                       -0.635352
# 93690                                       -0.635352
# 93691                                        0.469074
# 93693                                       -0.635352
# 93695                                       -0.635352
# 93696                                       -0.635352
# 93697                                        1.128662
# 93699                                       -0.635352
# 93701                                       -0.251870
# 93702                                       -0.098478
#
#                 Cereals, not cooked or NS as to cooked   Cheeses   \
# participant_id
# 83732                                         -0.539209 -0.542523
# 83733                                         -0.539209 -0.542523
# 83734                                         -0.539209 -0.542523
# 83735                                         -0.539209 -0.542523
# 83736                                         -0.539209 -0.542523
# 83737                                          1.465546  0.111238
# 83738                                         -0.002221  0.111238
# 83739                                         -0.539209 -0.542523
# 83741                                          2.514821 -0.542523
# 83742                                         -0.539209 -0.542523
# 83744                                         -0.539209 -0.542523
# 83745                                         -0.539209 -0.542523
# 83747                                         -0.539209 -0.228718
# 83748                                          0.892759  0.204632
# 83749                                          1.608743 -0.542523
# 83750                                         -0.539209  0.111238
# 83751                                         -0.539209  0.336941
# 83752                                         -0.539209  0.111238
# 83753                                          2.038333 -0.542523
# 83754                                         -0.539209 -0.542523
# 83755                                          0.454219 -0.542523
# 83756                                          2.736418 -0.542523
# 83757                                         -0.539209  0.764999
# 83759                                         -0.539209 -0.227161
# 83760                                          0.454219 -0.542523
# 83761                                         -0.539209 -0.542523
# 83762                                          0.534767 -0.542523
# 83764                                         -0.539209  6.679977
# 83766                                          1.476644 -0.542523
# 83767                                         -0.539209 -0.542523
# ...                                                 ...       ...
# 93660                                          1.322349  1.231971
# 93661                                         -0.539209  1.263102
# 93663                                         -0.539209 -0.542523
# 93664                                          1.606595  0.340054
# 93665                                         -0.539209 -0.542523
# 93667                                         -0.539209 -0.542523
# 93668                                          0.024628 -0.402431
# 93669                                          0.615315 -0.542523
# 93670                                         -0.539209  0.792394
# 93671                                          0.534767 -0.542523
# 93675                                         -0.539209  0.497580
# 93676                                          1.000156 -0.542523
# 93677                                         -0.539209  0.340054
# 93680                                          1.000156  0.111238
# 93682                                          0.892759  1.503437
# 93683                                          0.140975 -0.487420
# 93684                                         -0.539209  3.068727
# 93685                                         -0.539209 -0.542523
# 93686                                         -0.539209 -0.542523
# 93687                                         -0.539209 -0.542523
# 93689                                         -0.539209  0.111238
# 93690                                         -0.539209 -0.142172
# 93691                                         -0.539209 -0.542523
# 93693                                          2.056233 -0.542523
# 93695                                         -0.539209  0.111238
# 93696                                          0.373670  0.675340
# 93697                                         -0.539209 -0.360715
# 93699                                          0.561616 -0.542523
# 93701                                         -0.539209  1.014051
# 93702                                         -0.539209  0.056758
#
#                 Citrus fruits, juices   \
# participant_id
# 83732                         1.215913
# 83733                        -0.498846
# 83734                        -0.498846
# 83735                        -0.498846
# 83736                         0.358534
# 83737                         0.179913
# 83738                         0.287086
# 83739                        -0.498846
# 83741                        -0.498846
# 83742                         0.621999
# 83744                        -0.498846
# 83745                        -0.498846
# 83747                        -0.498846
# 83748                        -0.498846
# 83749                        -0.498846
# 83750                        -0.498846
# 83751                        -0.498846
# 83752                         1.300758
# 83753                        -0.498846
# 83754                         2.269776
# 83755                         0.358534
# 83756                         1.014965
# 83757                        -0.498846
# 83759                         1.294060
# 83760                        -0.498846
# 83761                        -0.498846
# 83762                        -0.498846
# 83764                        -0.498846
# 83766                        -0.498846
# 83767                        -0.400604
# ...                                ...
# 93660                        -0.498846
# 93661                        -0.498846
# 93663                         0.613962
# 93664                        -0.498846
# 93665                         1.215913
# 93667                         1.162327
# 93668                        -0.498846
# 93669                        -0.498846
# 93670                        -0.498846
# 93671                         0.671120
# 93675                         2.426069
# 93676                        -0.498846
# 93677                        -0.498846
# 93680                        -0.498846
# 93682                        -0.498846
# 93683                         1.162327
# 93684                        -0.498846
# 93685                        -0.288966
# 93686                        -0.445259
# 93687                        -0.498846
# 93689                        -0.498846
# 93690                         1.112135
# 93691                         0.399706
# 93693                        -0.498846
# 93695                        -0.445259
# 93696                        -0.498846
# 93697                        -0.498846
# 93699                        -0.498846
# 93701                        -0.498846
# 93702                        -0.498846
#
#                 Crackers and salty snacks from grain products   \
# participant_id
# 83732                                                 0.705366
# 83733                                                -0.621731
# 83734                                                 0.537667
# 83735                                                 0.247818
# 83736                                                -0.621731
# 83737                                                -0.621731
# 83738                                                 0.853603
# 83739                                                 0.620481
# 83741                                                -0.621731
# 83742                                                -0.266044
# 83744                                                -0.621731
# 83745                                                -0.621731
# 83747                                                -0.621731
# 83748                                                 0.123597
# 83749                                                -0.621731
# 83750                                                -0.621731
# 83751                                                 2.897870
# 83752                                                -0.621731
# 83753                                                 1.138070
# 83754                                                -0.621731
# 83755                                                -0.621731
# 83756                                                 0.648224
# 83757                                                 0.123597
# 83759                                                 3.249830
# 83760                                                -0.621731
# 83761                                                -0.621731
# 83762                                                -0.621731
# 83764                                                 1.726050
# 83766                                                 0.750086
# 83767                                                -0.621731
# ...                                                        ...
# 93660                                                 1.416325
# 93661                                                -0.621731
# 93663                                                -0.621731
# 93664                                                 0.646568
# 93665                                                -0.062735
# 93667                                                 0.154652
# 93668                                                -0.621731
# 93669                                                -0.621731
# 93670                                                 2.005134
# 93671                                                -0.621731
# 93675                                                -0.621731
# 93676                                                -0.621731
# 93677                                                 1.629986
# 93680                                                 2.897870
# 93682                                                 5.175259
# 93683                                                 0.465205
# 93684                                                 0.826275
# 93685                                                 0.537667
# 93686                                                -0.621731
# 93687                                                -0.621731
# 93689                                                 0.033743
# 93690                                                -0.621731
# 93691                                                -0.621731
# 93693                                                 0.646568
# 93695                                                -0.124846
# 93696                                                 0.372039
# 93697                                                 0.123597
# 93699                                                 1.138070
# 93701                                                -0.621731
# 93702                                                -0.621731
#
#                 Creams and cream substitutes   Dark-green vegetables   \
# participant_id
# 83732                               -0.181967                1.301009
# 83733                               -0.352918               -0.321501
# 83734                                0.102370               -0.321501
# 83735                                0.548353               -0.321501
# 83736                               -0.352918               -0.321501
# 83737                               -0.352918               -0.321501
# 83738                               -0.352918               -0.321501
# 83739                               -0.352918               -0.321501
# 83741                                1.391477                3.814308
# 83742                                0.519280               -0.321501
# 83744                               -0.352918               -0.321501
# 83745                               -0.352918               -0.321501
# 83747                               -0.352918               -0.321501
# 83748                               -0.352918               -0.321501
# 83749                               -0.352918               -0.321501
# 83750                               -0.352918               -0.321501
# 83751                               -0.352918               -0.321501
# 83752                               -0.352918               -0.321501
# 83753                               -0.352918               -0.321501
# 83754                               -0.352918               -0.321501
# 83755                               -0.352918               -0.321501
# 83756                               -0.352918               -0.321501
# 83757                                3.135872               -0.321501
# 83759                                0.483229               -0.321501
# 83760                               -0.352918               -0.321501
# 83761                               -0.352918               -0.321501
# 83762                               -0.352918               -0.321501
# 83764                               -0.352918               -0.321501
# 83766                               -0.352918               -0.321501
# 83767                               -0.352918               -0.321501
# ...                                       ...                     ...
# 93660                               -0.352918               -0.321501
# 93661                               -0.352918               -0.321501
# 93663                               -0.352918               -0.321501
# 93664                               -0.352918               -0.321501
# 93665                                2.263675               -0.321501
# 93667                               -0.352918               -0.321501
# 93668                               -0.352918                1.796033
# 93669                               -0.352918               -0.321501
# 93670                               -0.352918               -0.321501
# 93671                               -0.352918               -0.321501
# 93675                                0.955379               -0.321501
# 93676                               -0.124983               -0.321501
# 93677                               -0.352918                0.611707
# 93680                               -0.352918               -0.321501
# 93682                               -0.352918               -0.255116
# 93683                               -0.352918               -0.321501
# 93684                               -0.352918               -0.321501
# 93685                               -0.352918               -0.321501
# 93686                               -0.352918               -0.321501
# 93687                               -0.352918               -0.321501
# 93689                                0.330304               -0.321501
# 93690                               -0.352918               -0.321501
# 93691                               -0.352918               -0.321501
# 93693                               -0.352918               -0.321501
# 93695                               -0.062185               -0.321501
# 93696                               -0.352918               -0.321501
# 93697                               -0.352918                0.055600
# 93699                                1.100745                0.026543
# 93701                               -0.352918               -0.321501
# 93702                               -0.352918                1.163148
#
#                 Deep-yellow vegetables           ...           \
# participant_id                                   ...
# 83732                         -0.288015          ...
# 83733                         -0.288015          ...
# 83734                         -0.288015          ...
# 83735                         -0.288015          ...
# 83736                         -0.288015          ...
# 83737                         -0.288015          ...
# 83738                         -0.288015          ...
# 83739                         -0.288015          ...
# 83741                         -0.288015          ...
# 83742                         -0.288015          ...
# 83744                         -0.288015          ...
# 83745                         -0.288015          ...
# 83747                         -0.288015          ...
# 83748                         -0.288015          ...
# 83749                         -0.288015          ...
# 83750                         -0.288015          ...
# 83751                         -0.288015          ...
# 83752                         -0.288015          ...
# 83753                         -0.288015          ...
# 83754                         -0.288015          ...
# 83755                          6.670079          ...
# 83756                         -0.288015          ...
# 83757                         -0.288015          ...
# 83759                         -0.288015          ...
# 83760                         -0.288015          ...
# 83761                         -0.288015          ...
# 83762                         -0.288015          ...
# 83764                         -0.288015          ...
# 83766                         -0.288015          ...
# 83767                         -0.288015          ...
# ...                                 ...          ...
# 93660                         -0.288015          ...
# 93661                         -0.288015          ...
# 93663                         -0.288015          ...
# 93664                         -0.288015          ...
# 93665                         -0.288015          ...
# 93667                         -0.288015          ...
# 93668                         -0.288015          ...
# 93669                         -0.288015          ...
# 93670                         -0.288015          ...
# 93671                          0.931308          ...
# 93675                         -0.288015          ...
# 93676                         -0.288015          ...
# 93677                          0.937935          ...
# 93680                         -0.288015          ...
# 93682                         -0.288015          ...
# 93683                         -0.288015          ...
# 93684                         -0.288015          ...
# 93685                         -0.288015          ...
# 93686                         -0.288015          ...
# 93687                         -0.288015          ...
# 93689                         -0.288015          ...
# 93690                         -0.288015          ...
# 93691                         -0.288015          ...
# 93693                         -0.288015          ...
# 93695                         -0.288015          ...
# 93696                          1.169871          ...
# 93697                         -0.288015          ...
# 93699                         -0.288015          ...
# 93701                         -0.288015          ...
# 93702                          0.440928          ...
#
#                 Sandwiches with meat, poultry, fish   \
# participant_id
# 83732                                       1.636382
# 83733                                      -0.526308
# 83734                                       1.859012
# 83735                                       2.039236
# 83736                                      -0.526308
# 83737                                      -0.526308
# 83738                                       4.244331
# 83739                                       0.555037
# 83741                                      -0.526308
# 83742                                       0.698686
# 83744                                       1.275933
# 83745                                      -0.526308
# 83747                                      -0.526308
# 83748                                       0.666352
# 83749                                      -0.526308
# 83750                                       2.177054
# 83751                                       0.374813
# 83752                                      -0.526308
# 83753                                       2.548104
# 83754                                      -0.526308
# 83755                                      -0.526308
# 83756                                      -0.526308
# 83757                                      -0.526308
# 83759                                       0.555037
# 83760                                       1.699990
# 83761                                      -0.526308
# 83762                                       1.943823
# 83764                                       0.555037
# 83766                                      -0.526308
# 83767                                       1.795403
# ...                                              ...
# 93660                                      -0.526308
# 93661                                      -0.526308
# 93663                                      -0.526308
# 93664                                       1.567473
# 93665                                      -0.526308
# 93667                                       0.348309
# 93668                                      -0.526308
# 93669                                      -0.526308
# 93670                                      -0.526308
# 93671                                      -0.526308
# 93675                                      -0.526308
# 93676                                       1.169919
# 93677                                      -0.526308
# 93680                                      -0.526308
# 93682                                      -0.526308
# 93683                                      -0.526308
# 93684                                      -0.526308
# 93685                                      -0.526308
# 93686                                      -0.526308
# 93687                                       0.692855
# 93689                                      -0.526308
# 93690                                       1.222926
# 93691                                      -0.526308
# 93693                                      -0.526308
# 93695                                      -0.526308
# 93696                                      -0.526308
# 93697                                      -0.526308
# 93699                                       1.445556
# 93701                                      -0.526308
# 93702                                      -0.526308
#
#                 Seeds and seed mixtures   \
# participant_id
# 83732                          -0.111702
# 83733                          -0.111702
# 83734                          -0.111702
# 83735                          -0.111702
# 83736                          -0.111702
# 83737                          -0.111702
# 83738                          -0.111702
# 83739                          -0.111702
# 83741                          -0.111702
# 83742                          -0.111702
# 83744                          -0.111702
# 83745                          -0.111702
# 83747                          -0.111702
# 83748                          -0.111702
# 83749                          -0.111702
# 83750                          -0.111702
# 83751                          -0.111702
# 83752                          -0.111702
# 83753                          -0.111702
# 83754                          -0.111702
# 83755                          -0.111702
# 83756                          -0.111702
# 83757                          -0.111702
# 83759                          -0.111702
# 83760                          -0.111702
# 83761                          -0.111702
# 83762                          -0.111702
# 83764                          -0.111702
# 83766                          -0.111702
# 83767                          -0.111702
# ...                                  ...
# 93660                          -0.111702
# 93661                          -0.111702
# 93663                          -0.111702
# 93664                          -0.111702
# 93665                          -0.111702
# 93667                          -0.111702
# 93668                          -0.111702
# 93669                          -0.111702
# 93670                          -0.111702
# 93671                          -0.111702
# 93675                          -0.111702
# 93676                          -0.111702
# 93677                           0.487351
# 93680                          -0.111702
# 93682                          -0.111702
# 93683                          -0.111702
# 93684                          -0.111702
# 93685                          -0.111702
# 93686                          -0.111702
# 93687                          -0.111702
# 93689                          -0.111702
# 93690                          -0.111702
# 93691                          -0.111702
# 93693                          -0.111702
# 93695                          -0.111702
# 93696                          -0.111702
# 93697                          -0.111702
# 93699                          -0.111702
# 93701                          -0.111702
# 93702                          -0.111702
#
#                 Soups, broths, extracts from meat, poultry, fish base   \
# participant_id
# 83732                                                   -0.225953
# 83733                                                   -0.225953
# 83734                                                   -0.225953
# 83735                                                   -0.225953
# 83736                                                   -0.225953
# 83737                                                   -0.225953
# 83738                                                   -0.225953
# 83739                                                   -0.225953
# 83741                                                   -0.225953
# 83742                                                   -0.225953
# 83744                                                   -0.225953
# 83745                                                   -0.225953
# 83747                                                   -0.225953
# 83748                                                   -0.225953
# 83749                                                   -0.225953
# 83750                                                   -0.225953
# 83751                                                   -0.225953
# 83752                                                   -0.225953
# 83753                                                   -0.225953
# 83754                                                   -0.225953
# 83755                                                   -0.225953
# 83756                                                   -0.225953
# 83757                                                   -0.225953
# 83759                                                   -0.225953
# 83760                                                   -0.225953
# 83761                                                   -0.225953
# 83762                                                   -0.225953
# 83764                                                   -0.225953
# 83766                                                   -0.225953
# 83767                                                    4.739883
# ...                                                           ...
# 93660                                                    4.192035
# 93661                                                   -0.225953
# 93663                                                   -0.225953
# 93664                                                   -0.225953
# 93665                                                   -0.225953
# 93667                                                   -0.225953
# 93668                                                   -0.225953
# 93669                                                   -0.225953
# 93670                                                   -0.225953
# 93671                                                   -0.225953
# 93675                                                   -0.225953
# 93676                                                    4.068824
# 93677                                                   -0.225953
# 93680                                                   -0.225953
# 93682                                                   -0.225953
# 93683                                                   -0.225953
# 93684                                                   -0.225953
# 93685                                                   -0.225953
# 93686                                                   -0.225953
# 93687                                                   -0.225953
# 93689                                                   -0.225953
# 93690                                                   -0.225953
# 93691                                                   -0.225953
# 93693                                                   -0.225953
# 93695                                                   -0.225953
# 93696                                                   -0.225953
# 93697                                                   -0.225953
# 93699                                                   -0.225953
# 93701                                                   -0.225953
# 93702                                                   -0.225953
#
#                 Sugars and sweets   Tomatoes and tomato mixtures   \
# participant_id
# 83732                    -0.391486                      -0.068325
# 83733                    -0.256012                       1.941238
# 83734                    -0.486223                       0.009521
# 83735                    -0.149275                      -0.458532
# 83736                    -0.091486                      -0.458532
# 83737                    -0.263275                      -0.458532
# 83738                    -0.486223                       0.112145
# 83739                    -0.019802                      -0.458532
# 83741                     1.092726                      -0.165877
# 83742                    -0.316644                      -0.458532
# 83744                    -0.486223                      -0.360980
# 83745                    -0.486223                      -0.458532
# 83747                    -0.091486                      -0.154951
# 83748                    -0.486223                      -0.458532
# 83749                    -0.486223                      -0.458532
# 83750                     1.092726                      -0.312204
# 83751                    -0.359907                      -0.458532
# 83752                    -0.486223                       1.297397
# 83753                    -0.138854                       1.573664
# 83754                     0.446620                       0.321881
# 83755                     0.903252                      -0.030280
# 83756                    -0.486223                       1.142095
# 83757                    -0.486223                      -0.068325
# 83759                     0.099883                      -0.458532
# 83760                     0.356620                       0.712088
# 83761                    -0.223170                       2.966310
# 83762                    -0.486223                      -0.111248
# 83764                    -0.486223                      -0.458532
# 83766                    -0.486223                      -0.458532
# 83767                    -0.486223                      -0.458532
# ...                            ...                            ...
# 93660                    -0.323276                      -0.458532
# 93661                     0.303251                      -0.458532
# 93663                    -0.486223                      -0.443704
# 93664                    -0.486223                      -0.458532
# 93665                     0.195883                      -0.458532
# 93667                     2.750623                      -0.458532
# 93668                    -0.423065                       0.068247
# 93669                    -0.280960                      -0.458532
# 93670                     0.934831                      -0.458532
# 93671                    -0.486223                       0.126778
# 93675                     0.066725                       0.010301
# 93676                    -0.486223                      -0.165877
# 93677                    -0.012223                       1.970504
# 93680                     0.264409                      -0.458532
# 93682                    -0.486223                      -0.458532
# 93683                     1.629569                      -0.336592
# 93684                    -0.486223                       0.321881
# 93685                    -0.454644                       0.191943
# 93686                    -0.486223                      -0.458532
# 93687                    -0.486223                      -0.357273
# 93689                    -0.165381                      -0.458532
# 93690                    -0.328328                      -0.458532
# 93691                    -0.223170                      -0.458532
# 93693                    -0.065275                      -0.458532
# 93695                     1.619148                       0.078002
# 93696                     0.375883                      -0.165877
# 93697                    -0.140749                      -0.263428
# 93699                     0.066409                       0.526740
# 93701                     0.334830                       4.831302
# 93702                    -0.486223                       1.570542
#
#                 Vegetables and mixtures mostly vegetables baby food   \
# participant_id
# 83732                                                   -0.018331
# 83733                                                   -0.018331
# 83734                                                   -0.018331
# 83735                                                   -0.018331
# 83736                                                   -0.018331
# 83737                                                   -0.018331
# 83738                                                   -0.018331
# 83739                                                   -0.018331
# 83741                                                   -0.018331
# 83742                                                   -0.018331
# 83744                                                   -0.018331
# 83745                                                   -0.018331
# 83747                                                   -0.018331
# 83748                                                   -0.018331
# 83749                                                   -0.018331
# 83750                                                   -0.018331
# 83751                                                   -0.018331
# 83752                                                   -0.018331
# 83753                                                   -0.018331
# 83754                                                   -0.018331
# 83755                                                   -0.018331
# 83756                                                   -0.018331
# 83757                                                   -0.018331
# 83759                                                   -0.018331
# 83760                                                   -0.018331
# 83761                                                   -0.018331
# 83762                                                   -0.018331
# 83764                                                   -0.018331
# 83766                                                   -0.018331
# 83767                                                   -0.018331
# ...                                                           ...
# 93660                                                   -0.018331
# 93661                                                   -0.018331
# 93663                                                   -0.018331
# 93664                                                   -0.018331
# 93665                                                   -0.018331
# 93667                                                   -0.018331
# 93668                                                   -0.018331
# 93669                                                   -0.018331
# 93670                                                   -0.018331
# 93671                                                   -0.018331
# 93675                                                   -0.018331
# 93676                                                   -0.018331
# 93677                                                   -0.018331
# 93680                                                   -0.018331
# 93682                                                   -0.018331
# 93683                                                   -0.018331
# 93684                                                   -0.018331
# 93685                                                   -0.018331
# 93686                                                   -0.018331
# 93687                                                   -0.018331
# 93689                                                   -0.018331
# 93690                                                   -0.018331
# 93691                                                   -0.018331
# 93693                                                   -0.018331
# 93695                                                   -0.018331
# 93696                                                   -0.018331
# 93697                                                   -0.018331
# 93699                                                   -0.018331
# 93701                                                   -0.018331
# 93702                                                   -0.018331
#
#                 Vegetables with meat, poultry, fish   Water, noncarbonated   \
# participant_id
# 83732                                      -0.032501              -0.416625
# 83733                                      -0.032501              -0.119051
# 83734                                      -0.032501              -0.068178
# 83735                                      -0.032501              -0.556004
# 83736                                      -0.032501              -0.806885
# 83737                                      -0.032501              -0.250206
# 83738                                      -0.032501              -0.461923
# 83739                                      -0.032501              -0.305122
# 83741                                      -0.032501              -0.001276
# 83742                                      -0.032501              -0.322683
# 83744                                      -0.032501              -0.369933
# 83745                                      -0.032501              -0.806885
# 83747                                      -0.032501              -0.100235
# 83748                                      -0.032501              -0.305122
# 83749                                      -0.032501              -0.305122
# 83750                                      -0.032501               1.200170
# 83751                                      -0.032501              -0.202678
# 83752                                      -0.032501              -0.272716
# 83753                                      -0.032501              -0.119051
# 83754                                      -0.032501              -0.397976
# 83755                                      -0.032501              -0.305122
# 83756                                      -0.032501               1.814831
# 83757                                      -0.032501              -0.373543
# 83759                                      -0.032501              -0.629177
# 83760                                      -0.032501              -0.806885
# 83761                                      -0.032501               0.539514
# 83762                                      -0.032501               0.320146
# 83764                                      -0.032501               0.405711
# 83766                                      -0.032501              -0.242401
# 83767                                      -0.032501              -0.619421
# ...                                              ...                    ...
# 93660                                      -0.032501               0.008481
# 93661                                      -0.032501              -0.137867
# 93663                                      -0.032501              -0.354601
# 93664                                      -0.032501              -0.100235
# 93665                                      -0.032501              -0.118173
# 93667                                      -0.032501              -0.420109
# 93668                                      -0.032501              -0.453560
# 93669                                      -0.032501              -0.609427
# 93670                                      -0.032501               0.142954
# 93671                                      -0.032501               4.846321
# 93675                                      -0.032501               1.144419
# 93676                                      -0.032501              -0.137867
# 93677                                      -0.032501               0.201869
# 93680                                      -0.032501              -0.806885
# 93682                                      -0.032501              -0.553021
# 93683                                      -0.032501              -0.360873
# 93684                                      -0.032501               0.447524
# 93685                                      -0.032501              -0.379341
# 93686                                      -0.032501              -0.806885
# 93687                                      -0.032501              -0.806885
# 93689                                      -0.032501              -0.401809
# 93690                                      -0.032501              -0.806885
# 93691                                      -0.032501              -0.326028
# 93693                                      -0.032501              -0.137867
# 93695                                      -0.032501              -0.105252
# 93696                                      -0.032501               4.545263
# 93697                                      -0.032501              -0.486314
# 93699                                      -0.032501              -0.215640
# 93701                                      -0.032501              -0.650084
# 93702                                      -0.032501              -0.213132
#
#                 White potatoes and Puerto Rican starchy vegetables   \
# participant_id
# 83732                                                    1.655569
# 83733                                                   -0.636411
# 83734                                                    2.480682
# 83735                                                    0.455183
# 83736                                                   -0.563068
# 83737                                                   -0.636411
# 83738                                                   -0.636411
# 83739                                                   -0.636411
# 83741                                                    2.419562
# 83742                                                   -0.636411
# 83744                                                    0.326220
# 83745                                                   -0.636411
# 83747                                                   -0.636411
# 83748                                                    0.433179
# 83749                                                   -0.025217
# 83750                                                    0.005343
# 83751                                                   -0.636411
# 83752                                                    0.451515
# 83753                                                    0.570698
# 83754                                                   -0.636411
# 83755                                                    1.082635
# 83756                                                   -0.636411
# 83757                                                   -0.636411
# 83759                                                   -0.107483
# 83760                                                   -0.066411
# 83761                                                   -0.636411
# 83762                                                    0.708217
# 83764                                                   -0.098560
# 83766                                                   -0.636411
# 83767                                                   -0.636411
# ...                                                           ...
# 93660                                                   -0.025217
# 93661                                                   -0.636411
# 93663                                                   -0.636411
# 93664                                                   -0.636411
# 93665                                                    1.637233
# 93667                                                   -0.049664
# 93668                                                   -0.566368
# 93669                                                    0.891576
# 93670                                                    1.368307
# 93671                                                   -0.636411
# 93675                                                   -0.636411
# 93676                                                    0.616538
# 93677                                                   -0.636411
# 93680                                                    0.142862
# 93682                                                    0.488187
# 93683                                                   -0.636411
# 93684                                                   -0.636411
# 93685                                                    1.655569
# 93686                                                   -0.636411
# 93687                                                    1.563890
# 93689                                                   -0.636411
# 93690                                                    0.364359
# 93691                                                   -0.636411
# 93693                                                    0.451515
# 93695                                                    1.117718
# 93696                                                   -0.636411
# 93697                                                    0.127582
# 93699                                                   -0.636411
# 93701                                                   -0.636411
# 93702                                                   -0.636411
#
#                 Yeast breads, rolls
# participant_id
# 83732                       0.666359
# 83733                       0.679067
# 83734                       1.111123
# 83735                      -0.947498
# 83736                      -0.947498
# 83737                       0.882387
# 83738                       0.475746
# 83739                      -0.235876
# 83741                      -0.947498
# 83742                       1.060293
# 83744                      -0.947498
# 83745                       1.898990
# 83747                      -0.947498
# 83748                       0.475746
# 83749                       0.145350
# 83750                       0.475746
# 83751                      -0.947498
# 83752                      -0.015527
# 83753                       1.339858
# 83754                       0.475746
# 83755                       0.094520
# 83756                       1.136538
# 83757                       0.179152
# 83759                       0.526576
# 83760                       0.170765
# 83761                      -0.947498
# 83762                       0.145350
# 83764                       0.323256
# 83766                       2.407291
# 83767                      -0.947498
# ...                              ...
# 93660                       0.907802
# 93661                       0.323256
# 93663                       0.513869
# 93664                      -0.947498
# 93665                       1.225491
# 93667                      -0.947498
# 93668                      -0.235876
# 93669                      -0.007140
# 93670                       0.005567
# 93671                       0.755312
# 93675                       1.204396
# 93676                      -0.947498
# 93677                      -0.947498
# 93680                      -0.947498
# 93682                      -0.553564
# 93683                      -0.947498
# 93684                       0.780727
# 93685                      -0.947498
# 93686                      -0.185046
# 93687                      -0.947498
# 93689                       0.297840
# 93690                       0.653651
# 93691                       0.624170
# 93693                       0.323256
# 93695                      -0.000787
# 93696                       1.250906
# 93697                      -0.051617
# 93699                      -0.947498
# 93701                       1.051397
# 93702                      -0.947498
#
# [7697 rows x 56 columns]

# %%
# first two components really cannot separate high and low mortality very effectively

# %% [markdown]
# # Plot first two components
#
# Next section (i.e. four components) is more important than this

# %%
####----
# reference: https://towardsdatascience.com/dive-into-pca-principal-component-analysis-with-python-43ded13ead21


pca_components_cont = pca.components_[0:2]

plt.matshow(pca_components_cont, cmap='viridis')
plt.yticks([0,1],['1st Comp','2nd Comp'],fontsize=10)
plt.colorbar()
#plt.xticks(range(1, len(df_esrdonly.columns)),df_esrdonly.columns[1:len(df_esrdonly.columns)],rotation=65)
plt.xticks(range(len(standardisedX.columns)),standardisedX.columns,rotation=65,ha='left')
#plt.tight_layout()
plt.savefig('../../progress_reports/to_submit/pca_univariate_bivariate/pca_food_groups_what_contributes_to_PCA_components' + '.png')            
plt.show() # 
# from the abobe plot, Vegetable, Grain, Protein contribute the most to the 1st component

# %% [markdown]
# # First Four components

# %%
# reference: https://towardsdatascience.com/dive-into-pca-principal-component-analysis-with-python-43ded13ead21
plt.rcParams['figure.figsize'] = 30, 16
components_to_count = 4

pca_components_cont = pca.components_[0:components_to_count]
ylabels = []

for c in range (components_to_count):
    ylabels.append('Component ' + str(c) )

xlabels = []    
for c in range (components_to_count):
    xlabels.append(c) 
    
plt.matshow(pca_components_cont, cmap='viridis')
plt.yticks(xlabels, ylabels, fontsize=10)
plt.colorbar()
plt.xlabel('\nContributors to the first five components')
plt.xticks(range(len(standardisedX.columns)), standardisedX.columns, rotation=90, ha='left')
plt.show()#

# %%
standardisedX.columns
# Out:
# Index(['Alcoholic beverages ', 'Beef', 'Cakes, cookies, pies, pastries, bars ',
#        'Cereals, not cooked or NS as to cooked ', 'Cheeses ',
#        'Citrus fruits, juices ',
#        'Crackers and salty snacks from grain products ',
#        'Creams and cream substitutes ', 'Dark-green vegetables ',
#        'Deep-yellow vegetables ', 'Dried fruits ', 'Egg mixtures',
#        'Egg substitutes ', 'Eggs', 'Fats', 'Fish and shellfish ',
#        'Formulated nutrition beverages, energy drinks, sports drinks, functional beverages ',
#        'Frankfurters, sausages, lunchmeats, meat spreads',
#        'Frozen or shelf-stable plate meals with meat, poultry, fish as major ingredient ',
#        'Fruit juices and nectars excluding citrus ',
#        'Fruits and juices baby food ',
#        'Grain mixtures, frozen plate meals, soups ',
#        'Gravies from meat, poultry, fish base ',
#        'Lamb, veal, game, other carcass meat ', 'Legumes ',
#        'Meat substitutes, mainly cereal protein ', 'Meat, NS as to type ',
#        'Meat, poultry, fish in gravy or sauce or creamed ',
#        'Meat, poultry, fish with starch item (includes white potatoes) ',
#        'Meat, poultry, fish with starch item and vegetables ',
#        'Meat, poultry, fish with vegetables (excluding white potatoes) ',
#        'Milk desserts, sauces, gravies ', 'Milks and milk drinks ',
#        'Mixtures mostly vegetables without meat, poultry, fish ',
#        'Nonalcoholic beverages ', 'Nuts, nut butters, and nut mixtures ',
#        'Oils ', 'Organ meats and mixtures ', 'Other fruits ',
#        'Other vegetables ',
#        'Pancakes, waffles, French toast, other grain products ',
#        'Pastas, cooked cereals, rice ', 'Pork', 'Poultry', 'Quick breads ',
#        'Salad dressings ', 'Sandwiches with meat, poultry, fish ',
#        'Seeds and seed mixtures ',
#        'Soups, broths, extracts from meat, poultry, fish base ',
#        'Sugars and sweets ', 'Tomatoes and tomato mixtures ',
#        'Vegetables and mixtures mostly vegetables baby food ',
#        'Vegetables with meat, poultry, fish ', 'Water, noncarbonated ',
#        'White potatoes and Puerto Rican starchy vegetables ',
#        'Yeast breads, rolls '],
#       dtype='object')

# %% [markdown]
# First five components explain the data by 90%
#
# Contributors for the First Component:
# Positively: Avg Milks and milk drinks  taken ->  (0.4)
#
# Negatively (-0.3 to -0.4) contributing: Actual Dark-green vegetables, Actual Starchy vegetables, Actual Whole grains,
# Avg Meat Poultry and Eggs subgroup, Avg Oils taken, Avg Water noncarbonated intake, Avg Nonalcoholic beverages taken
#
# Contributors for 2nd Component:
# Positively: Actual Red and orange vegetables Intake, Actual Other vegetables
# Negatively: 'Avg Nuts, Seeds, and Soy Products', 'Avg Added Sugars/Sugars and sweets', 'Avg Alcoholic beverages'
#
# Contributors for 3rd component:
# Positively: 'Actual Taken Refined grains amount', 'Avg Milk desserts, sauces, gravies taken'
# Negatively: Avg Water noncarbonated intake'
#
# -------------------------------------------
# Features that do not contribute much:
# 'Avg Seafood taken', 'Avg Solid Fats taken',
#
# ---------------------------------------------
#
# Considering all Five Components:
#
# Positively the most contributing:
# 'Actual Taken Refined grains amount',  'Avg Milk desserts, sauces, gravies taken'  'Avg Nuts, Seeds, and Soy Products taken',
# 'Actual Red and orange vegetables Intake'
#
# Most Negatively:
# 'Actual Other vegetables Intake',  'Avg Added Sugars/Sugars and sweets taken', Avg Alcoholic beverages intake
#
# ---
#
# # Can do regression with all food sub groups except 'Avg Seafood taken', 'Avg Solid Fats taken'. Though will do a comparison with them as well

# %%
standardisedX_important = standardisedX_with_target #.drop(['Avg Seafood taken', 'Avg Solid Fats taken'], axis=1)

# %%
standardisedX_important.head()
# Out:
#                 Alcoholic beverages       Beef  \
# participant_id
# 83732                      -0.276774  1.746677
# 83733                       4.198610 -0.354007
# 83734                      -0.276774  1.747975
# 83735                      -0.276774 -0.354007
# 83736                      -0.276774 -0.354007
#
#                 Cakes, cookies, pies, pastries, bars   \
# participant_id
# 83732                                        0.285003
# 83733                                        8.476163
# 83734                                       -0.635352
# 83735                                       -0.635352
# 83736                                       -0.635352
#
#                 Cereals, not cooked or NS as to cooked   Cheeses   \
# participant_id
# 83732                                         -0.539209 -0.542523
# 83733                                         -0.539209 -0.542523
# 83734                                         -0.539209 -0.542523
# 83735                                         -0.539209 -0.542523
# 83736                                         -0.539209 -0.542523
#
#                 Citrus fruits, juices   \
# participant_id
# 83732                         1.215913
# 83733                        -0.498846
# 83734                        -0.498846
# 83735                        -0.498846
# 83736                         0.358534
#
#                 Crackers and salty snacks from grain products   \
# participant_id
# 83732                                                 0.705366
# 83733                                                -0.621731
# 83734                                                 0.537667
# 83735                                                 0.247818
# 83736                                                -0.621731
#
#                 Creams and cream substitutes   Dark-green vegetables   \
# participant_id
# 83732                               -0.181967                1.301009
# 83733                               -0.352918               -0.321501
# 83734                                0.102370               -0.321501
# 83735                                0.548353               -0.321501
# 83736                               -0.352918               -0.321501
#
#                 Deep-yellow vegetables   \
# participant_id
# 83732                         -0.288015
# 83733                         -0.288015
# 83734                         -0.288015
# 83735                         -0.288015
# 83736                         -0.288015
#
#                                          ...                            \
# participant_id                           ...
# 83732                                    ...
# 83733                                    ...
# 83734                                    ...
# 83735                                    ...
# 83736                                    ...
#
#                 Tomatoes and tomato mixtures   \
# participant_id
# 83732                               -0.068325
# 83733                                1.941238
# 83734                                0.009521
# 83735                               -0.458532
# 83736                               -0.458532
#
#                 Vegetables and mixtures mostly vegetables baby food   \
# participant_id
# 83732                                                   -0.018331
# 83733                                                   -0.018331
# 83734                                                   -0.018331
# 83735                                                   -0.018331
# 83736                                                   -0.018331
#
#                 Vegetables with meat, poultry, fish   Water, noncarbonated   \
# participant_id
# 83732                                      -0.032501              -0.416625
# 83733                                      -0.032501              -0.119051
# 83734                                      -0.032501              -0.068178
# 83735                                      -0.032501              -0.556004
# 83736                                      -0.032501              -0.806885
#
#                 White potatoes and Puerto Rican starchy vegetables   \
# participant_id
# 83732                                                    1.655569
# 83733                                                   -0.636411
# 83734                                                    2.480682
# 83735                                                    0.455183
# 83736                                                   -0.563068
#
#                 Yeast breads, rolls   \
# participant_id
# 83732                       0.666359
# 83733                       0.679067
# 83734                       1.111123
# 83735                      -0.947498
# 83736                      -0.947498
#
#                 ESRD patients: Avg. Annual Mortality rates  \
# participant_id
# 83732                                             0.567883
# 83733                                             0.051317
# 83734                                             2.098045
# 83735                                             0.296672
# 83736                                            -0.296316
#
#                 Dialysis patients: Avg. Annual Mortality rates  \
# participant_id
# 83732                                                 0.680335
# 83733                                                 0.132554
# 83734                                                 2.063622
# 83735                                                 0.393165
# 83736                                                -0.286306
#
#                 ESRD patients: Total (or %) deaths for target year  \
# participant_id
# 83732                                                    1.416787
# 83733                                                    0.260991
# 83734                                                    1.863595
# 83735                                                    0.838380
# 83736                                                   -0.413016
#
#                 Dialysis patients: Total (or %) deaths for target year
# participant_id
# 83732                                                    1.392000
# 83733                                                    0.259228
# 83734                                                    1.871845
# 83735                                                    0.831566
# 83736                                                   -0.412344
#
# [5 rows x 60 columns]

# %%
standardisedX_important.corr()
# Out:
#                                                     Alcoholic beverages   \
# Alcoholic beverages                                             1.000000
# Beef                                                            0.038373
# Cakes, cookies, pies, pastries, bars                           -0.013569
# Cereals, not cooked or NS as to cooked                         -0.034089
# Cheeses                                                         0.008948
# Citrus fruits, juices                                          -0.033827
# Crackers and salty snacks from grain products                  -0.003072
# Creams and cream substitutes                                    0.039223
# Dark-green vegetables                                           0.013675
# Deep-yellow vegetables                                         -0.006399
# Dried fruits                                                   -0.003261
# Egg mixtures                                                    0.010387
# Egg substitutes                                                 0.001995
# Eggs                                                            0.022834
# Fats                                                            0.004380
# Fish and shellfish                                              0.042237
# Formulated nutrition beverages, energy drinks, ...              0.020351
# Frankfurters, sausages, lunchmeats, meat spreads                0.033416
# Frozen or shelf-stable plate meals with meat, p...              0.018366
# Fruit juices and nectars excluding citrus                      -0.052405
# Fruits and juices baby food                                    -0.008550
# Grain mixtures, frozen plate meals, soups                       0.052973
# Gravies from meat, poultry, fish base                           0.046607
# Lamb, veal, game, other carcass meat                           -0.005209
# Legumes                                                         0.014793
# Meat substitutes, mainly cereal protein                        -0.003991
# Meat, NS as to type                                             0.010615
# Meat, poultry, fish in gravy or sauce or creamed                0.009005
# Meat, poultry, fish with starch item (includes ...              0.003798
# Meat, poultry, fish with starch item and vegeta...              0.035127
# Meat, poultry, fish with vegetables (excluding ...              0.004129
# Milk desserts, sauces, gravies                                 -0.035971
# Milks and milk drinks                                          -0.064502
# Mixtures mostly vegetables without meat, poultr...             -0.009807
# Nonalcoholic beverages                                          0.111740
# Nuts, nut butters, and nut mixtures                            -0.008901
# Oils                                                            0.006694
# Organ meats and mixtures                                        0.007702
# Other fruits                                                   -0.054626
# Other vegetables                                                0.010108
# Pancakes, waffles, French toast, other grain pr...             -0.032161
# Pastas, cooked cereals, rice                                   -0.023973
# Pork                                                            0.062209
# Poultry                                                         0.031915
# Quick breads                                                    0.005537
# Salad dressings                                                 0.036078
# Sandwiches with meat, poultry, fish                             0.051826
# Seeds and seed mixtures                                         0.002083
# Soups, broths, extracts from meat, poultry, fis...             -0.011486
# Sugars and sweets                                              -0.015772
# Tomatoes and tomato mixtures                                    0.019111
# Vegetables and mixtures mostly vegetables baby ...             -0.000758
# Vegetables with meat, poultry, fish                             0.023465
# Water, noncarbonated                                            0.072806
# White potatoes and Puerto Rican starchy vegetab...              0.043217
# Yeast breads, rolls                                             0.014702
# ESRD patients: Avg. Annual Mortality rates                      0.007024
# Dialysis patients: Avg. Annual Mortality rates                  0.015139
# ESRD patients: Total (or %) deaths for target year              0.031561
# Dialysis patients: Total (or %) deaths for targ...              0.030322
#
#                                                         Beef  \
# Alcoholic beverages                                 0.038373
# Beef                                                1.000000
# Cakes, cookies, pies, pastries, bars                0.022873
# Cereals, not cooked or NS as to cooked              0.003625
# Cheeses                                             0.000391
# Citrus fruits, juices                               0.041133
# Crackers and salty snacks from grain products      -0.011529
# Creams and cream substitutes                        0.020187
# Dark-green vegetables                               0.008142
# Deep-yellow vegetables                              0.024185
# Dried fruits                                        0.026257
# Egg mixtures                                        0.002847
# Egg substitutes                                    -0.019735
# Eggs                                                0.041240
# Fats                                                0.037419
# Fish and shellfish                                  0.011076
# Formulated nutrition beverages, energy drinks, ...  0.005639
# Frankfurters, sausages, lunchmeats, meat spreads    0.020436
# Frozen or shelf-stable plate meals with meat, p... -0.016288
# Fruit juices and nectars excluding citrus          -0.019584
# Fruits and juices baby food                        -0.005243
# Grain mixtures, frozen plate meals, soups          -0.009852
# Gravies from meat, poultry, fish base               0.046124
# Lamb, veal, game, other carcass meat               -0.015171
# Legumes                                             0.016842
# Meat substitutes, mainly cereal protein            -0.005105
# Meat, NS as to type                                -0.005265
# Meat, poultry, fish in gravy or sauce or creamed    0.000514
# Meat, poultry, fish with starch item (includes ...  0.003316
# Meat, poultry, fish with starch item and vegeta... -0.011119
# Meat, poultry, fish with vegetables (excluding ... -0.016779
# Milk desserts, sauces, gravies                      0.016952
# Milks and milk drinks                              -0.003335
# Mixtures mostly vegetables without meat, poultr...  0.006581
# Nonalcoholic beverages                              0.069129
# Nuts, nut butters, and nut mixtures                -0.019799
# Oils                                               -0.005058
# Organ meats and mixtures                            0.008143
# Other fruits                                        0.012261
# Other vegetables                                    0.031592
# Pancakes, waffles, French toast, other grain pr... -0.026763
# Pastas, cooked cereals, rice                        0.016521
# Pork                                               -0.001611
# Poultry                                            -0.006915
# Quick breads                                        0.033116
# Salad dressings                                     0.034148
# Sandwiches with meat, poultry, fish                -0.013523
# Seeds and seed mixtures                            -0.019519
# Soups, broths, extracts from meat, poultry, fis... -0.012926
# Sugars and sweets                                  -0.002820
# Tomatoes and tomato mixtures                        0.039564
# Vegetables and mixtures mostly vegetables baby ... -0.003570
# Vegetables with meat, poultry, fish                 0.005311
# Water, noncarbonated                                0.034765
# White potatoes and Puerto Rican starchy vegetab...  0.102050
# Yeast breads, rolls                                 0.042619
# ESRD patients: Avg. Annual Mortality rates          0.026293
# Dialysis patients: Avg. Annual Mortality rates      0.027494
# ESRD patients: Total (or %) deaths for target year  0.041688
# Dialysis patients: Total (or %) deaths for targ...  0.041454
#
#                                                     Cakes, cookies, pies, pastries, bars   \
# Alcoholic beverages                                                             -0.013569
# Beef                                                                             0.022873
# Cakes, cookies, pies, pastries, bars                                             1.000000
# Cereals, not cooked or NS as to cooked                                           0.058101
# Cheeses                                                                          0.031721
# Citrus fruits, juices                                                            0.013408
# Crackers and salty snacks from grain products                                    0.012752
# Creams and cream substitutes                                                     0.050592
# Dark-green vegetables                                                           -0.006534
# Deep-yellow vegetables                                                           0.007758
# Dried fruits                                                                     0.020056
# Egg mixtures                                                                     0.020274
# Egg substitutes                                                                  0.000147
# Eggs                                                                             0.017904
# Fats                                                                             0.039535
# Fish and shellfish                                                               0.001301
# Formulated nutrition beverages, energy drinks, ...                               0.004037
# Frankfurters, sausages, lunchmeats, meat spreads                                 0.029797
# Frozen or shelf-stable plate meals with meat, p...                               0.010753
# Fruit juices and nectars excluding citrus                                        0.011775
# Fruits and juices baby food                                                      0.006616
# Grain mixtures, frozen plate meals, soups                                        0.015407
# Gravies from meat, poultry, fish base                                            0.034236
# Lamb, veal, game, other carcass meat                                            -0.009611
# Legumes                                                                          0.012981
# Meat substitutes, mainly cereal protein                                          0.001898
# Meat, NS as to type                                                              0.012264
# Meat, poultry, fish in gravy or sauce or creamed                                 0.011834
# Meat, poultry, fish with starch item (includes ...                               0.038676
# Meat, poultry, fish with starch item and vegeta...                               0.025779
# Meat, poultry, fish with vegetables (excluding ...                               0.055314
# Milk desserts, sauces, gravies                                                   0.082370
# Milks and milk drinks                                                            0.040903
# Mixtures mostly vegetables without meat, poultr...                               0.008649
# Nonalcoholic beverages                                                           0.033016
# Nuts, nut butters, and nut mixtures                                              0.002352
# Oils                                                                             0.001186
# Organ meats and mixtures                                                         0.007635
# Other fruits                                                                    -0.001725
# Other vegetables                                                                 0.004534
# Pancakes, waffles, French toast, other grain pr...                              -0.010994
# Pastas, cooked cereals, rice                                                    -0.007564
# Pork                                                                             0.016478
# Poultry                                                                          0.013985
# Quick breads                                                                     0.034336
# Salad dressings                                                                  0.020397
# Sandwiches with meat, poultry, fish                                              0.020703
# Seeds and seed mixtures                                                         -0.005948
# Soups, broths, extracts from meat, poultry, fis...                               0.004796
# Sugars and sweets                                                                0.012967
# Tomatoes and tomato mixtures                                                     0.015710
# Vegetables and mixtures mostly vegetables baby ...                              -0.011647
# Vegetables with meat, poultry, fish                                             -0.016369
# Water, noncarbonated                                                            -0.023074
# White potatoes and Puerto Rican starchy vegetab...                               0.039560
# Yeast breads, rolls                                                              0.032782
# ESRD patients: Avg. Annual Mortality rates                                       0.048692
# Dialysis patients: Avg. Annual Mortality rates                                   0.046665
# ESRD patients: Total (or %) deaths for target year                               0.042994
# Dialysis patients: Total (or %) deaths for targ...                               0.043995
#
#                                                     Cereals, not cooked or NS as to cooked   \
# Alcoholic beverages                                                               -0.034089
# Beef                                                                               0.003625
# Cakes, cookies, pies, pastries, bars                                               0.058101
# Cereals, not cooked or NS as to cooked                                             1.000000
# Cheeses                                                                            0.021594
# Citrus fruits, juices                                                              0.022395
# Crackers and salty snacks from grain products                                      0.050874
# Creams and cream substitutes                                                      -0.007652
# Dark-green vegetables                                                             -0.021798
# Deep-yellow vegetables                                                             0.010771
# Dried fruits                                                                       0.026656
# Egg mixtures                                                                      -0.057998
# Egg substitutes                                                                   -0.016897
# Eggs                                                                              -0.050745
# Fats                                                                              -0.023430
# Fish and shellfish                                                                -0.018819
# Formulated nutrition beverages, energy drinks, ...                                -0.003143
# Frankfurters, sausages, lunchmeats, meat spreads                                   0.001326
# Frozen or shelf-stable plate meals with meat, p...                                 0.016296
# Fruit juices and nectars excluding citrus                                          0.029497
# Fruits and juices baby food                                                        0.003461
# Grain mixtures, frozen plate meals, soups                                          0.034904
# Gravies from meat, poultry, fish base                                             -0.006390
# Lamb, veal, game, other carcass meat                                              -0.000603
# Legumes                                                                           -0.031601
# Meat substitutes, mainly cereal protein                                           -0.007775
# Meat, NS as to type                                                               -0.014749
# Meat, poultry, fish in gravy or sauce or creamed                                  -0.014811
# Meat, poultry, fish with starch item (includes ...                                 0.026319
# Meat, poultry, fish with starch item and vegeta...                                 0.010396
# Meat, poultry, fish with vegetables (excluding ...                                -0.005948
# Milk desserts, sauces, gravies                                                     0.059623
# Milks and milk drinks                                                              0.307142
# Mixtures mostly vegetables without meat, poultr...                                -0.028111
# Nonalcoholic beverages                                                            -0.014358
# Nuts, nut butters, and nut mixtures                                                0.029329
# Oils                                                                              -0.003965
# Organ meats and mixtures                                                           0.003892
# Other fruits                                                                       0.048386
# Other vegetables                                                                  -0.023465
# Pancakes, waffles, French toast, other grain pr...                                -0.006351
# Pastas, cooked cereals, rice                                                      -0.056146
# Pork                                                                              -0.020055
# Poultry                                                                            0.013154
# Quick breads                                                                      -0.039726
# Salad dressings                                                                    0.004872
# Sandwiches with meat, poultry, fish                                                0.026004
# Seeds and seed mixtures                                                           -0.008611
# Soups, broths, extracts from meat, poultry, fis...                                -0.032275
# Sugars and sweets                                                                  0.029384
# Tomatoes and tomato mixtures                                                       0.011268
# Vegetables and mixtures mostly vegetables baby ...                                -0.007360
# Vegetables with meat, poultry, fish                                                0.005575
# Water, noncarbonated                                                              -0.030579
# White potatoes and Puerto Rican starchy vegetab...                                 0.020015
# Yeast breads, rolls                                                               -0.001341
# ESRD patients: Avg. Annual Mortality rates                                        -0.041666
# Dialysis patients: Avg. Annual Mortality rates                                    -0.049070
# ESRD patients: Total (or %) deaths for target year                                -0.057768
# Dialysis patients: Total (or %) deaths for targ...                                -0.057146
#
#                                                     Cheeses   \
# Alcoholic beverages                                 0.008948
# Beef                                                0.000391
# Cakes, cookies, pies, pastries, bars                0.031721
# Cereals, not cooked or NS as to cooked              0.021594
# Cheeses                                             1.000000
# Citrus fruits, juices                               0.004449
# Crackers and salty snacks from grain products       0.075023
# Creams and cream substitutes                        0.031486
# Dark-green vegetables                               0.000474
# Deep-yellow vegetables                              0.003347
# Dried fruits                                       -0.000587
# Egg mixtures                                        0.002004
# Egg substitutes                                    -0.000407
# Eggs                                               -0.002842
# Fats                                                0.026071
# Fish and shellfish                                 -0.012164
# Formulated nutrition beverages, energy drinks, ... -0.000426
# Frankfurters, sausages, lunchmeats, meat spreads    0.095706
# Frozen or shelf-stable plate meals with meat, p...  0.017819
# Fruit juices and nectars excluding citrus           0.002923
# Fruits and juices baby food                        -0.002094
# Grain mixtures, frozen plate meals, soups           0.013343
# Gravies from meat, poultry, fish base               0.014981
# Lamb, veal, game, other carcass meat               -0.011138
# Legumes                                            -0.008651
# Meat substitutes, mainly cereal protein            -0.007823
# Meat, NS as to type                                -0.003795
# Meat, poultry, fish in gravy or sauce or creamed    0.008281
# Meat, poultry, fish with starch item (includes ... -0.013791
# Meat, poultry, fish with starch item and vegeta...  0.006964
# Meat, poultry, fish with vegetables (excluding ... -0.006870
# Milk desserts, sauces, gravies                      0.035192
# Milks and milk drinks                               0.036169
# Mixtures mostly vegetables without meat, poultr... -0.003892
# Nonalcoholic beverages                              0.067972
# Nuts, nut butters, and nut mixtures                 0.000033
# Oils                                                0.028825
# Organ meats and mixtures                           -0.013683
# Other fruits                                        0.009640
# Other vegetables                                    0.011475
# Pancakes, waffles, French toast, other grain pr... -0.003989
# Pastas, cooked cereals, rice                       -0.024705
# Pork                                                0.011818
# Poultry                                             0.005979
# Quick breads                                       -0.011314
# Salad dressings                                     0.078097
# Sandwiches with meat, poultry, fish                -0.000655
# Seeds and seed mixtures                            -0.006286
# Soups, broths, extracts from meat, poultry, fis... -0.038218
# Sugars and sweets                                   0.028034
# Tomatoes and tomato mixtures                        0.059603
# Vegetables and mixtures mostly vegetables baby ... -0.007336
# Vegetables with meat, poultry, fish                -0.003398
# Water, noncarbonated                                0.012080
# White potatoes and Puerto Rican starchy vegetab...  0.049972
# Yeast breads, rolls                                 0.094932
# ESRD patients: Avg. Annual Mortality rates          0.013990
# Dialysis patients: Avg. Annual Mortality rates      0.014158
# ESRD patients: Total (or %) deaths for target year  0.018911
# Dialysis patients: Total (or %) deaths for targ...  0.018741
#
#                                                     Citrus fruits, juices   \
# Alcoholic beverages                                              -0.033827
# Beef                                                              0.041133
# Cakes, cookies, pies, pastries, bars                              0.013408
# Cereals, not cooked or NS as to cooked                            0.022395
# Cheeses                                                           0.004449
# Citrus fruits, juices                                             1.000000
# Crackers and salty snacks from grain products                    -0.009843
# Creams and cream substitutes                                     -0.001096
# Dark-green vegetables                                             0.012934
# Deep-yellow vegetables                                           -0.005424
# Dried fruits                                                      0.001499
# Egg mixtures                                                      0.043743
# Egg substitutes                                                   0.006224
# Eggs                                                              0.039226
# Fats                                                              0.013048
# Fish and shellfish                                                0.005199
# Formulated nutrition beverages, energy drinks, ...               -0.002348
# Frankfurters, sausages, lunchmeats, meat spreads                  0.022566
# Frozen or shelf-stable plate meals with meat, p...               -0.010803
# Fruit juices and nectars excluding citrus                         0.033550
# Fruits and juices baby food                                       0.001948
# Grain mixtures, frozen plate meals, soups                         0.041253
# Gravies from meat, poultry, fish base                             0.003978
# Lamb, veal, game, other carcass meat                             -0.020725
# Legumes                                                           0.031893
# Meat substitutes, mainly cereal protein                          -0.005068
# Meat, NS as to type                                              -0.001797
# Meat, poultry, fish in gravy or sauce or creamed                 -0.004258
# Meat, poultry, fish with starch item (includes ...                0.003689
# Meat, poultry, fish with starch item and vegeta...                0.017448
# Meat, poultry, fish with vegetables (excluding ...                0.001646
# Milk desserts, sauces, gravies                                    0.017589
# Milks and milk drinks                                             0.023425
# Mixtures mostly vegetables without meat, poultr...                0.000743
# Nonalcoholic beverages                                           -0.040780
# Nuts, nut butters, and nut mixtures                               0.003325
# Oils                                                              0.001252
# Organ meats and mixtures                                         -0.024033
# Other fruits                                                      0.050570
# Other vegetables                                                  0.010129
# Pancakes, waffles, French toast, other grain pr...                0.053264
# Pastas, cooked cereals, rice                                      0.032294
# Pork                                                              0.009227
# Poultry                                                           0.001640
# Quick breads                                                      0.056285
# Salad dressings                                                   0.005551
# Sandwiches with meat, poultry, fish                              -0.012344
# Seeds and seed mixtures                                          -0.012575
# Soups, broths, extracts from meat, poultry, fis...                0.024118
# Sugars and sweets                                                 0.018831
# Tomatoes and tomato mixtures                                      0.032932
# Vegetables and mixtures mostly vegetables baby ...               -0.008713
# Vegetables with meat, poultry, fish                               0.005526
# Water, noncarbonated                                             -0.004242
# White potatoes and Puerto Rican starchy vegetab...                0.011049
# Yeast breads, rolls                                               0.051625
# ESRD patients: Avg. Annual Mortality rates                        0.003038
# Dialysis patients: Avg. Annual Mortality rates                    0.000429
# ESRD patients: Total (or %) deaths for target year               -0.011560
# Dialysis patients: Total (or %) deaths for targ...               -0.010933
#
#                                                     Crackers and salty snacks from grain products   \
# Alcoholic beverages                                                                      -0.003072
# Beef                                                                                     -0.011529
# Cakes, cookies, pies, pastries, bars                                                      0.012752
# Cereals, not cooked or NS as to cooked                                                    0.050874
# Cheeses                                                                                   0.075023
# Citrus fruits, juices                                                                    -0.009843
# Crackers and salty snacks from grain products                                             1.000000
# Creams and cream substitutes                                                              0.007385
# Dark-green vegetables                                                                    -0.011244
# Deep-yellow vegetables                                                                   -0.000829
# Dried fruits                                                                             -0.008358
# Egg mixtures                                                                             -0.006688
# Egg substitutes                                                                          -0.001738
# Eggs                                                                                     -0.010505
# Fats                                                                                      0.024761
# Fish and shellfish                                                                       -0.008164
# Formulated nutrition beverages, energy drinks, ...                                        0.020270
# Frankfurters, sausages, lunchmeats, meat spreads                                          0.044093
# Frozen or shelf-stable plate meals with meat, p...                                        0.009029
# Fruit juices and nectars excluding citrus                                                 0.014453
# Fruits and juices baby food                                                               0.007412
# Grain mixtures, frozen plate meals, soups                                                 0.044504
# Gravies from meat, poultry, fish base                                                     0.040475
# Lamb, veal, game, other carcass meat                                                     -0.018737
# Legumes                                                                                  -0.032525
# Meat substitutes, mainly cereal protein                                                   0.013398
# Meat, NS as to type                                                                      -0.013316
# Meat, poultry, fish in gravy or sauce or creamed                                          0.006924
# Meat, poultry, fish with starch item (includes ...                                        0.013759
# Meat, poultry, fish with starch item and vegeta...                                       -0.007386
# Meat, poultry, fish with vegetables (excluding ...                                       -0.007190
# Milk desserts, sauces, gravies                                                            0.043552
# Milks and milk drinks                                                                     0.039866
# Mixtures mostly vegetables without meat, poultr...                                        0.005039
# Nonalcoholic beverages                                                                    0.024471
# Nuts, nut butters, and nut mixtures                                                       0.019046
# Oils                                                                                     -0.016863
# Organ meats and mixtures                                                                 -0.007225
# Other fruits                                                                              0.009167
# Other vegetables                                                                          0.013242
# Pancakes, waffles, French toast, other grain pr...                                       -0.001003
# Pastas, cooked cereals, rice                                                             -0.049238
# Pork                                                                                      0.004028
# Poultry                                                                                   0.021558
# Quick breads                                                                             -0.019021
# Salad dressings                                                                           0.029232
# Sandwiches with meat, poultry, fish                                                       0.030997
# Seeds and seed mixtures                                                                   0.000278
# Soups, broths, extracts from meat, poultry, fis...                                       -0.010570
# Sugars and sweets                                                                         0.042267
# Tomatoes and tomato mixtures                                                              0.040296
# Vegetables and mixtures mostly vegetables baby ...                                       -0.006665
# Vegetables with meat, poultry, fish                                                       0.004902
# Water, noncarbonated                                                                     -0.000997
# White potatoes and Puerto Rican starchy vegetab...                                        0.019666
# Yeast breads, rolls                                                                      -0.002209
# ESRD patients: Avg. Annual Mortality rates                                               -0.096117
# Dialysis patients: Avg. Annual Mortality rates                                           -0.097898
# ESRD patients: Total (or %) deaths for target year                                       -0.090857
# Dialysis patients: Total (or %) deaths for targ...                                       -0.091880
#
#                                                     Creams and cream substitutes   \
# Alcoholic beverages                                                      0.039223
# Beef                                                                     0.020187
# Cakes, cookies, pies, pastries, bars                                     0.050592
# Cereals, not cooked or NS as to cooked                                  -0.007652
# Cheeses                                                                  0.031486
# Citrus fruits, juices                                                   -0.001096
# Crackers and salty snacks from grain products                            0.007385
# Creams and cream substitutes                                             1.000000
# Dark-green vegetables                                                    0.002409
# Deep-yellow vegetables                                                   0.000760
# Dried fruits                                                             0.009219
# Egg mixtures                                                             0.034239
# Egg substitutes                                                          0.000220
# Eggs                                                                     0.018887
# Fats                                                                     0.055517
# Fish and shellfish                                                       0.016874
# Formulated nutrition beverages, energy drinks, ...                       0.020534
# Frankfurters, sausages, lunchmeats, meat spreads                        -0.004471
# Frozen or shelf-stable plate meals with meat, p...                       0.022952
# Fruit juices and nectars excluding citrus                               -0.001746
# Fruits and juices baby food                                             -0.003457
# Grain mixtures, frozen plate meals, soups                                0.032384
# Gravies from meat, poultry, fish base                                    0.008686
# Lamb, veal, game, other carcass meat                                     0.016277
# Legumes                                                                  0.024267
# Meat substitutes, mainly cereal protein                                  0.001199
# Meat, NS as to type                                                     -0.010316
# Meat, poultry, fish in gravy or sauce or creamed                         0.034665
# Meat, poultry, fish with starch item (includes ...                       0.010602
# Meat, poultry, fish with starch item and vegeta...                       0.017435
# Meat, poultry, fish with vegetables (excluding ...                       0.017693
# Milk desserts, sauces, gravies                                           0.023668
# Milks and milk drinks                                                   -0.001978
# Mixtures mostly vegetables without meat, poultr...                       0.000737
# Nonalcoholic beverages                                                   0.102302
# Nuts, nut butters, and nut mixtures                                      0.012930
# Oils                                                                     0.018016
# Organ meats and mixtures                                                -0.005672
# Other fruits                                                            -0.003441
# Other vegetables                                                         0.033752
# Pancakes, waffles, French toast, other grain pr...                       0.016703
# Pastas, cooked cereals, rice                                            -0.001812
# Pork                                                                     0.009792
# Poultry                                                                  0.006366
# Quick breads                                                             0.036607
# Salad dressings                                                          0.060799
# Sandwiches with meat, poultry, fish                                      0.000796
# Seeds and seed mixtures                                                 -0.000882
# Soups, broths, extracts from meat, poultry, fis...                      -0.003282
# Sugars and sweets                                                        0.027688
# Tomatoes and tomato mixtures                                             0.045994
# Vegetables and mixtures mostly vegetables baby ...                      -0.006469
# Vegetables with meat, poultry, fish                                     -0.001661
# Water, noncarbonated                                                     0.024026
# White potatoes and Puerto Rican starchy vegetab...                       0.034622
# Yeast breads, rolls                                                      0.033584
# ESRD patients: Avg. Annual Mortality rates                               0.058666
# Dialysis patients: Avg. Annual Mortality rates                           0.064038
# ESRD patients: Total (or %) deaths for target year                       0.076958
# Dialysis patients: Total (or %) deaths for targ...                       0.076986
#
#                                                     Dark-green vegetables   \
# Alcoholic beverages                                               0.013675
# Beef                                                              0.008142
# Cakes, cookies, pies, pastries, bars                             -0.006534
# Cereals, not cooked or NS as to cooked                           -0.021798
# Cheeses                                                           0.000474
# Citrus fruits, juices                                             0.012934
# Crackers and salty snacks from grain products                    -0.011244
# Creams and cream substitutes                                      0.002409
# Dark-green vegetables                                             1.000000
# Deep-yellow vegetables                                            0.084082
# Dried fruits                                                      0.023891
# Egg mixtures                                                      0.018708
# Egg substitutes                                                  -0.004682
# Eggs                                                              0.047569
# Fats                                                              0.001560
# Fish and shellfish                                                0.082832
# Formulated nutrition beverages, energy drinks, ...               -0.014320
# Frankfurters, sausages, lunchmeats, meat spreads                  0.003016
# Frozen or shelf-stable plate meals with meat, p...               -0.010349
# Fruit juices and nectars excluding citrus                        -0.000571
# Fruits and juices baby food                                      -0.000081
# Grain mixtures, frozen plate meals, soups                        -0.026141
# Gravies from meat, poultry, fish base                             0.010201
# Lamb, veal, game, other carcass meat                              0.043526
# Legumes                                                           0.047654
# Meat substitutes, mainly cereal protein                          -0.003560
# Meat, NS as to type                                               0.000562
# Meat, poultry, fish in gravy or sauce or creamed                  0.006669
# Meat, poultry, fish with starch item (includes ...                0.004314
# Meat, poultry, fish with starch item and vegeta...               -0.010754
# Meat, poultry, fish with vegetables (excluding ...                0.018575
# Milk desserts, sauces, gravies                                    0.000547
# Milks and milk drinks                                            -0.017355
# Mixtures mostly vegetables without meat, poultr...                0.012484
# Nonalcoholic beverages                                            0.020370
# Nuts, nut butters, and nut mixtures                               0.019691
# Oils                                                              0.034201
# Organ meats and mixtures                                          0.002162
# Other fruits                                                      0.029390
# Other vegetables                                                  0.068198
# Pancakes, waffles, French toast, other grain pr...               -0.000801
# Pastas, cooked cereals, rice                                      0.096975
# Pork                                                              0.052692
# Poultry                                                           0.049431
# Quick breads                                                      0.001246
# Salad dressings                                                   0.035098
# Sandwiches with meat, poultry, fish                              -0.031048
# Seeds and seed mixtures                                           0.016388
# Soups, broths, extracts from meat, poultry, fis...                0.007806
# Sugars and sweets                                                 0.008226
# Tomatoes and tomato mixtures                                      0.022517
# Vegetables and mixtures mostly vegetables baby ...               -0.004024
# Vegetables with meat, poultry, fish                              -0.002463
# Water, noncarbonated                                              0.029530
# White potatoes and Puerto Rican starchy vegetab...               -0.005897
# Yeast breads, rolls                                              -0.006267
# ESRD patients: Avg. Annual Mortality rates                        0.032223
# Dialysis patients: Avg. Annual Mortality rates                    0.036443
# ESRD patients: Total (or %) deaths for target year                0.048180
# Dialysis patients: Total (or %) deaths for targ...                0.047648
#
#                                                     Deep-yellow vegetables   \
# Alcoholic beverages                                               -0.006399
# Beef                                                               0.024185
# Cakes, cookies, pies, pastries, bars                               0.007758
# Cereals, not cooked or NS as to cooked                             0.010771
# Cheeses                                                            0.003347
# Citrus fruits, juices                                             -0.005424
# Crackers and salty snacks from grain products                     -0.000829
# Creams and cream substitutes                                       0.000760
# Dark-green vegetables                                              0.084082
# Deep-yellow vegetables                                             1.000000
# Dried fruits                                                       0.022055
# Egg mixtures                                                       0.026340
# Egg substitutes                                                   -0.002284
# Eggs                                                               0.023221
# Fats                                                               0.035695
# Fish and shellfish                                                 0.030466
# Formulated nutrition beverages, energy drinks, ...                -0.018120
# Frankfurters, sausages, lunchmeats, meat spreads                   0.010607
# Frozen or shelf-stable plate meals with meat, p...                 0.007348
# Fruit juices and nectars excluding citrus                          0.005246
# Fruits and juices baby food                                       -0.003264
# Grain mixtures, frozen plate meals, soups                         -0.026538
# Gravies from meat, poultry, fish base                              0.014572
# Lamb, veal, game, other carcass meat                               0.007925
# Legumes                                                            0.025652
# Meat substitutes, mainly cereal protein                           -0.004153
# Meat, NS as to type                                               -0.005882
# Meat, poultry, fish in gravy or sauce or creamed                  -0.024473
# Meat, poultry, fish with starch item (includes ...                 0.012179
# Meat, poultry, fish with starch item and vegeta...                -0.008667
# Meat, poultry, fish with vegetables (excluding ...                -0.004556
# Milk desserts, sauces, gravies                                     0.025183
# Milks and milk drinks                                              0.016653
# Mixtures mostly vegetables without meat, poultr...                 0.030814
# Nonalcoholic beverages                                            -0.014325
# Nuts, nut butters, and nut mixtures                                0.036057
# Oils                                                               0.023910
# Organ meats and mixtures                                          -0.000955
# ...
# Milks and milk drinks                                                                    -0.089146
# Mixtures mostly vegetables without meat, poultr...                                        0.005201
# Nonalcoholic beverages                                                                    0.089187
# Nuts, nut butters, and nut mixtures                                                       0.020925
# Oils                                                                                      0.066199
# Organ meats and mixtures                                                                  0.004964
# Other fruits                                                                              0.039166
# Other vegetables                                                                          0.110025
# Pancakes, waffles, French toast, other grain pr...                                       -0.065107
# Pastas, cooked cereals, rice                                                              0.038411
# Pork                                                                                      0.056675
# Poultry                                                                                  -0.075356
# Quick breads                                                                              0.017590
# Salad dressings                                                                           0.042602
# Sandwiches with meat, poultry, fish                                                      -0.089203
# Seeds and seed mixtures                                                                   0.003086
# Soups, broths, extracts from meat, poultry, fis...                                        0.038470
# Sugars and sweets                                                                        -0.016066
# Tomatoes and tomato mixtures                                                              0.068201
# Vegetables and mixtures mostly vegetables baby ...                                       -0.007787
# Vegetables with meat, poultry, fish                                                      -0.003888
# Water, noncarbonated                                                                     -0.014201
# White potatoes and Puerto Rican starchy vegetab...                                        0.069122
# Yeast breads, rolls                                                                       0.051153
# ESRD patients: Avg. Annual Mortality rates                                                0.994153
# Dialysis patients: Avg. Annual Mortality rates                                            1.000000
# ESRD patients: Total (or %) deaths for target year                                        0.868520
# Dialysis patients: Total (or %) deaths for targ...                                        0.883724
#
#                                                     ESRD patients: Total (or %) deaths for target year  \
# Alcoholic beverages                                                                          0.031561
# Beef                                                                                         0.041688
# Cakes, cookies, pies, pastries, bars                                                         0.042994
# Cereals, not cooked or NS as to cooked                                                      -0.057768
# Cheeses                                                                                      0.018911
# Citrus fruits, juices                                                                       -0.011560
# Crackers and salty snacks from grain products                                               -0.090857
# Creams and cream substitutes                                                                 0.076958
# Dark-green vegetables                                                                        0.048180
# Deep-yellow vegetables                                                                       0.069377
# Dried fruits                                                                                 0.047838
# Egg mixtures                                                                                 0.028778
# Egg substitutes                                                                              0.008815
# Eggs                                                                                         0.110017
# Fats                                                                                         0.148119
# Fish and shellfish                                                                           0.058146
# Formulated nutrition beverages, energy drinks, ...                                          -0.076890
# Frankfurters, sausages, lunchmeats, meat spreads                                             0.003520
# Frozen or shelf-stable plate meals with meat, p...                                           0.057681
# Fruit juices and nectars excluding citrus                                                   -0.061631
# Fruits and juices baby food                                                                 -0.011531
# Grain mixtures, frozen plate meals, soups                                                   -0.099189
# Gravies from meat, poultry, fish base                                                        0.039912
# Lamb, veal, game, other carcass meat                                                         0.008522
# Legumes                                                                                      0.075688
# Meat substitutes, mainly cereal protein                                                     -0.000068
# Meat, NS as to type                                                                          0.005979
# Meat, poultry, fish in gravy or sauce or creamed                                             0.024486
# Meat, poultry, fish with starch item (includes ...                                           0.014108
# Meat, poultry, fish with starch item and vegeta...                                           0.036466
# Meat, poultry, fish with vegetables (excluding ...                                           0.074337
# Milk desserts, sauces, gravies                                                               0.034145
# Milks and milk drinks                                                                       -0.097030
# Mixtures mostly vegetables without meat, poultr...                                           0.010003
# Nonalcoholic beverages                                                                       0.121241
# Nuts, nut butters, and nut mixtures                                                          0.024455
# Oils                                                                                         0.073769
# Organ meats and mixtures                                                                     0.005286
# Other fruits                                                                                 0.040025
# Other vegetables                                                                             0.112214
# Pancakes, waffles, French toast, other grain pr...                                          -0.072860
# Pastas, cooked cereals, rice                                                                 0.060725
# Pork                                                                                         0.066798
# Poultry                                                                                     -0.059620
# Quick breads                                                                                 0.038099
# Salad dressings                                                                              0.057910
# Sandwiches with meat, poultry, fish                                                         -0.067705
# Seeds and seed mixtures                                                                      0.009527
# Soups, broths, extracts from meat, poultry, fis...                                           0.049890
# Sugars and sweets                                                                           -0.019339
# Tomatoes and tomato mixtures                                                                 0.069544
# Vegetables and mixtures mostly vegetables baby ...                                          -0.013047
# Vegetables with meat, poultry, fish                                                         -0.001804
# Water, noncarbonated                                                                         0.000237
# White potatoes and Puerto Rican starchy vegetab...                                           0.071533
# Yeast breads, rolls                                                                          0.061607
# ESRD patients: Avg. Annual Mortality rates                                                   0.833901
# Dialysis patients: Avg. Annual Mortality rates                                               0.868520
# ESRD patients: Total (or %) deaths for target year                                           1.000000
# Dialysis patients: Total (or %) deaths for targ...                                           0.999415
#
#                                                     Dialysis patients: Total (or %) deaths for target year
# Alcoholic beverages                                                                          0.030322
# Beef                                                                                         0.041454
# Cakes, cookies, pies, pastries, bars                                                         0.043995
# Cereals, not cooked or NS as to cooked                                                      -0.057146
# Cheeses                                                                                      0.018741
# Citrus fruits, juices                                                                       -0.010933
# Crackers and salty snacks from grain products                                               -0.091880
# Creams and cream substitutes                                                                 0.076986
# Dark-green vegetables                                                                        0.047648
# Deep-yellow vegetables                                                                       0.069786
# Dried fruits                                                                                 0.047497
# Egg mixtures                                                                                 0.027979
# Egg substitutes                                                                              0.009579
# Eggs                                                                                         0.110976
# Fats                                                                                         0.149616
# Fish and shellfish                                                                           0.058003
# Formulated nutrition beverages, energy drinks, ...                                          -0.077034
# Frankfurters, sausages, lunchmeats, meat spreads                                             0.003206
# Frozen or shelf-stable plate meals with meat, p...                                           0.058532
# Fruit juices and nectars excluding citrus                                                   -0.061817
# Fruits and juices baby food                                                                 -0.010800
# Grain mixtures, frozen plate meals, soups                                                   -0.100892
# Gravies from meat, poultry, fish base                                                        0.040363
# Lamb, veal, game, other carcass meat                                                         0.008295
# Legumes                                                                                      0.074455
# Meat substitutes, mainly cereal protein                                                     -0.000233
# Meat, NS as to type                                                                          0.006867
# Meat, poultry, fish in gravy or sauce or creamed                                             0.024913
# Meat, poultry, fish with starch item (includes ...                                           0.013661
# Meat, poultry, fish with starch item and vegeta...                                           0.037160
# Meat, poultry, fish with vegetables (excluding ...                                           0.073866
# Milk desserts, sauces, gravies                                                               0.036121
# Milks and milk drinks                                                                       -0.096952
# Mixtures mostly vegetables without meat, poultr...                                           0.009371
# Nonalcoholic beverages                                                                       0.120590
# Nuts, nut butters, and nut mixtures                                                          0.024370
# Oils                                                                                         0.073654
# Organ meats and mixtures                                                                     0.005331
# Other fruits                                                                                 0.040409
# Other vegetables                                                                             0.112667
# Pancakes, waffles, French toast, other grain pr...                                          -0.072907
# Pastas, cooked cereals, rice                                                                 0.059716
# Pork                                                                                         0.066613
# Poultry                                                                                     -0.061159
# Quick breads                                                                                 0.037152
# Salad dressings                                                                              0.057559
# Sandwiches with meat, poultry, fish                                                         -0.069267
# Seeds and seed mixtures                                                                      0.009118
# Soups, broths, extracts from meat, poultry, fis...                                           0.049443
# Sugars and sweets                                                                           -0.018885
# Tomatoes and tomato mixtures                                                                 0.069882
# Vegetables and mixtures mostly vegetables baby ...                                          -0.013067
# Vegetables with meat, poultry, fish                                                         -0.001930
# Water, noncarbonated                                                                        -0.000753
# White potatoes and Puerto Rican starchy vegetab...                                           0.071984
# Yeast breads, rolls                                                                          0.061553
# ESRD patients: Avg. Annual Mortality rates                                                   0.851306
# Dialysis patients: Avg. Annual Mortality rates                                               0.883724
# ESRD patients: Total (or %) deaths for target year                                           0.999415
# Dialysis patients: Total (or %) deaths for targ...                                           1.000000
#
# [60 rows x 60 columns]

# %%
plt.figure(figsize=(30, 30))


corr = standardisedX_important.corr() #df_diff_ratio_with_mortality.corr()
sns.heatmap(corr, 
            xticklabels = corr.columns.values,
            yticklabels = corr.columns.values,
            annot = True,
           cmap="BuPu");
plt.suptitle('Heatmap, Correlation with Mortality Rates');
plt.savefig('heatmap-ckd-mortality-subgroup-regression-after-pca.png')
standardisedX_important.columns
# Out:
# Index(['Alcoholic beverages ', 'Beef', 'Cakes, cookies, pies, pastries, bars ',
#        'Cereals, not cooked or NS as to cooked ', 'Cheeses ',
#        'Citrus fruits, juices ',
#        'Crackers and salty snacks from grain products ',
#        'Creams and cream substitutes ', 'Dark-green vegetables ',
#        'Deep-yellow vegetables ', 'Dried fruits ', 'Egg mixtures',
#        'Egg substitutes ', 'Eggs', 'Fats', 'Fish and shellfish ',
#        'Formulated nutrition beverages, energy drinks, sports drinks, functional beverages ',
#        'Frankfurters, sausages, lunchmeats, meat spreads',
#        'Frozen or shelf-stable plate meals with meat, poultry, fish as major ingredient ',
#        'Fruit juices and nectars excluding citrus ',
#        'Fruits and juices baby food ',
#        'Grain mixtures, frozen plate meals, soups ',
#        'Gravies from meat, poultry, fish base ',
#        'Lamb, veal, game, other carcass meat ', 'Legumes ',
#        'Meat substitutes, mainly cereal protein ', 'Meat, NS as to type ',
#        'Meat, poultry, fish in gravy or sauce or creamed ',
#        'Meat, poultry, fish with starch item (includes white potatoes) ',
#        'Meat, poultry, fish with starch item and vegetables ',
#        'Meat, poultry, fish with vegetables (excluding white potatoes) ',
#        'Milk desserts, sauces, gravies ', 'Milks and milk drinks ',
#        'Mixtures mostly vegetables without meat, poultry, fish ',
#        'Nonalcoholic beverages ', 'Nuts, nut butters, and nut mixtures ',
#        'Oils ', 'Organ meats and mixtures ', 'Other fruits ',
#        'Other vegetables ',
#        'Pancakes, waffles, French toast, other grain products ',
#        'Pastas, cooked cereals, rice ', 'Pork', 'Poultry', 'Quick breads ',
#        'Salad dressings ', 'Sandwiches with meat, poultry, fish ',
#        'Seeds and seed mixtures ',
#        'Soups, broths, extracts from meat, poultry, fish base ',
#        'Sugars and sweets ', 'Tomatoes and tomato mixtures ',
#        'Vegetables and mixtures mostly vegetables baby food ',
#        'Vegetables with meat, poultry, fish ', 'Water, noncarbonated ',
#        'White potatoes and Puerto Rican starchy vegetables ',
#        'Yeast breads, rolls ', 'ESRD patients: Avg. Annual Mortality rates',
#        'Dialysis patients: Avg. Annual Mortality rates',
#        'ESRD patients: Total (or %) deaths for target year',
#        'Dialysis patients: Total (or %) deaths for target year'],
#       dtype='object')

# %% [markdown]
# # use the important Columns only

# %% [markdown]
# Most Positvely Correlated: 'Actual Other vegetables Intake',    'Actual Red and orange vegetables Intake', 'Actual Starchy vegetables Intake',
#
# Most Negatively Correlated: 'Avg Alcoholic beverages intake' (-0.79),    'Avg Added Sugars/Sugars and sweets taken' (-0.64), 'Avg Nuts, Seeds, and Soy Products taken' (-0.55)

# %% [markdown]
# # Check: the data  First block is not relevant

# %%
plt.rcParams['figure.figsize'] = 5, 5 
negatively_grains = standardisedX_with_target[ ['Actual Grain Intake', 'ESRD patients: Avg. Annual Mortality rates']]
negatively_grains.plot.line()
plt.title('Standardised.  Actual Grain Intake  \n and ESRD Mortality Rates')
plt.show()

negatively_grains = negatively_grains.sort_values(by='Actual Grain Intake', ascending=True)
#positively_other = positively[['Actual Other vegetables Intake', 'ESRD patients: Avg. Annual Mortality rates']]
negatively_grains.plot.line()
plt.title('Standardised. Actual Grain Intake  SORTED\n and ESRD Mortality Rates')
plt.savefig('positive_subgroup_line_1')
negatively_grains
plt.show()

plt.rcParams['figure.figsize'] = 5, 5
negatively_grains = df_esrdonly_actual_only[ ['Actual Grain Intake', 'ESRD patients: Avg. Annual Mortality rates']]
#positively_other = positively[['Actual Other vegetables Intake', 'ESRD patients: Avg. Annual Mortality rates']]
negatively_grains.plot.line()
plt.title('Raw data. Actual Grain Intake   \n and ESRD Mortality Rates')
plt.show()

plt.savefig('positive_subgroup_line_1')
negatively_grains

sns.pairplot(negatively_grains,   vars=negatively_grains.columns, size=5, kind='reg'); # diag_kind='kde',
plt.title('Raw data. Actual Grain Intake \n and ESRD Mortality Rates')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-55-b4b525c563c9> in <module>()
#       1 plt.rcParams['figure.figsize'] = 5, 5
# ----> 2 negatively_grains = standardisedX_with_target[ ['Actual Grain Intake', 'ESRD patients: Avg. Annual Mortality rates']]
#       3 negatively_grains.plot.line()
#       4 plt.title('Standardised.  Actual Grain Intake  \n and ESRD Mortality Rates')
#       5 plt.show()
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2677         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2678             # either boolean or fancy integer index
# -> 2679             return self._getitem_array(key)
#    2680         elif isinstance(key, DataFrame):
#    2681             return self._getitem_frame(key)
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\pandas\core\frame.py in _getitem_array(self, key)
#    2721             return self._take(indexer, axis=0)
#    2722         else:
# -> 2723             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2724             return self._take(indexer, axis=1)
#    2725
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1325                 if mask.any():
#    1326                     raise KeyError('{mask} not in index'
# -> 1327                                    .format(mask=objarr[mask]))
#    1328
#    1329                 return com._values_from_object(indexer)
#
# KeyError: "['Actual Grain Intake'] not in index"

# %%
plt.rcParams['figure.figsize'] = 5, 5 
positively = standardisedX_important[ ['Actual Other vegetables Intake', 'Actual Red and orange vegetables Intake', 'Actual Starchy vegetables Intake', 'ESRD patients: Avg. Annual Mortality rates']]

positively_other = positively[['Actual Other vegetables Intake', 'ESRD patients: Avg. Annual Mortality rates']]
positively_other.plot.line()
plt.savefig('positive_subgroup_line_1')
plt.title('Standardised.  Actual  Other vegetables Intake  \n and ESRD Mortality Rates')
plt.show()

positively_other = positively_other.sort_values(by=['Actual Other vegetables Intake'])
positively_other.plot.line()
plt.savefig('positive_subgroup_line_1')
plt.title('Standardised. Actual  Other vegetables Intake  \n and ESRD Mortality Rates')
plt.show()



#--------------------
positively_red = positively[['Actual Red and orange vegetables Intake', 'ESRD patients: Avg. Annual Mortality rates']]
positively_red.plot.line()
plt.savefig('positive_subgroup_line_2')

positively_starchy = positively[['Actual Starchy vegetables Intake', 'ESRD patients: Avg. Annual Mortality rates']]
positively_starchy.plot.line()
plt.savefig('positive_subgroup_line_3')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-54-55d17d068c9c> in <module>()
#       1 plt.rcParams['figure.figsize'] = 5, 5
# ----> 2 positively = standardisedX_important[ ['Actual Other vegetables Intake', 'Actual Red and orange vegetables Intake', 'Actual Starchy vegetables Intake', 'ESRD patients: Avg. Annual Mortality rates']]
#       3
#       4 positively_other = positively[['Actual Other vegetables Intake', 'ESRD patients: Avg. Annual Mortality rates']]
#       5 positively_other.plot.line()
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2677         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2678             # either boolean or fancy integer index
# -> 2679             return self._getitem_array(key)
#    2680         elif isinstance(key, DataFrame):
#    2681             return self._getitem_frame(key)
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\pandas\core\frame.py in _getitem_array(self, key)
#    2721             return self._take(indexer, axis=0)
#    2722         else:
# -> 2723             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2724             return self._take(indexer, axis=1)
#    2725
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1325                 if mask.any():
#    1326                     raise KeyError('{mask} not in index'
# -> 1327                                    .format(mask=objarr[mask]))
#    1328
#    1329                 return com._values_from_object(indexer)
#
# KeyError: "['Actual Other vegetables Intake'\n 'Actual Red and orange vegetables Intake'\n 'Actual Starchy vegetables Intake'] not in index"

# %%
negatively= standardisedX_important[ ['Avg Alcoholic beverages intake', 'Avg Added Sugars/Sugars and sweets taken', 'Avg Nuts, Seeds, and Soy Products taken',  'ESRD patients: Avg. Annual Mortality rates']]
negatively_alcohol = negatively[['Avg Alcoholic beverages intake', 'ESRD patients: Avg. Annual Mortality rates']]
negatively_alcohol.plot.line()
plt.savefig('./saved-images/negatively_subgroup_line_1')


negatively_alcohol = negatively_alcohol.sort_values(by=['Avg Alcoholic beverages intake'])
negatively_alcohol.plot.line()
plt.savefig('./saved-images/negatively_subgroup_line_1')


negatively= df_actual_only[ ['Avg Alcoholic beverages intake', 'Avg Added Sugars/Sugars and sweets taken', 'Avg Nuts, Seeds, and Soy Products taken',  'ESRD patients: Avg. Annual Mortality rates']]
negatively_alcohol = negatively[['Avg Alcoholic beverages intake', 'ESRD patients: Avg. Annual Mortality rates']]
negatively_alcohol.plot.line()
plt.savefig('./saved-images/negatively_subgroup_line_1')

sns.pairplot(negatively_alcohol,   vars=negatively_alcohol.columns, size=5, kind='reg'); # diag_kind='kde',
plt.title('Raw data. Avg Alcoholic beverages intake \n and ESRD Mortality Rates')
plt.show()

#---

negatively_sugar = negatively[['Avg Added Sugars/Sugars and sweets taken', 'ESRD patients: Avg. Annual Mortality rates']]
negatively_sugar.plot.line()
plt.savefig('./saved-images/negatively_subgroup_line_2')

sns.pairplot(negatively_sugar,   vars=negatively_sugar.columns, size=5, kind='reg'); # diag_kind='kde',
plt.title('Raw data. Avg Added Sugars/Sugars and sweets taken  \n and ESRD Mortality Rates')
plt.show()

#------

negatively_nuts = negatively[['Avg Nuts, Seeds, and Soy Products taken', 'ESRD patients: Avg. Annual Mortality rates']]
negatively_nuts.plot.line()
plt.savefig('./saved-images/negatively_subgroup_line_3')

sns.pairplot(negatively_nuts,   vars=negatively_nuts.columns, size=5, kind='reg'); # diag_kind='kde',
plt.title('Raw data. Avg Nuts, Seeds, and Soy Products taken  \n and ESRD Mortality Rates')
plt.show()

# https://www.statcan.gc.ca/eng/dai/btd/asr

# %%
plt.rcParams['figure.figsize'] = 5, 5 
positively = standardisedX_important[ ['Actual Other vegetables Intake', 'Actual Red and orange vegetables Intake', 'Actual Starchy vegetables Intake', 'ESRD patients: Avg. Annual Mortality rates']]

positively_other = positively[['Actual Other vegetables Intake', 'ESRD patients: Avg. Annual Mortality rates']]
positively_other.plot.line()
plt.savefig('positive_subgroup_line_1')
plt.title('Standardised.  Actual  Other vegetables Intake  \n and ESRD Mortality Rates')
plt.show()

positively_other = positively_other.sort_values(by=['Actual Other vegetables Intake'])
positively_other.plot.line()
plt.savefig('positive_subgroup_line_1')
plt.title('Standardised. Actual  Other vegetables Intake  \n and ESRD Mortality Rates')
plt.show()

# %% [markdown]
# # The following code were relevant for exploration phase. For experiment and methodology the above code are relevant

# %% [markdown]
# # Univariate
#
# Checked and plotted each column.
#
# Recommended intake amount is not included in the data (can be calculated like food groups)

# %%
"""
plt.figure(figsize=(16, 5));
#plt.rcParams['figure.figsize'] = 14, 14
df[' Actual Dark-green vegetables Intake'].plot.bar();
#plt.setxlabels(df['age_to'])
plt.suptitle('Actual Dark-green vegetables Intake')
plt.xticks(range(len(df[' Age-group: From USRDS'])), df[' Age-group: From USRDS']);
plt.xlabel('Age Group: From')
"""

# %%
df = pd.read_csv('./data-for-code/older_no-empty-cell-mortality_subgroup_data_june_9th_gender_neutral-based_data_after_processing.csv')
#plt.figure(figsize=(16, 5));
plt.rcParams['figure.figsize'] = 14, 7
df1 = df.iloc[:,3:6]
df2 = df.iloc[:,6:9]
df3 = df.iloc[:,9:12]
df4 = df.iloc[:,12:15]
df5 = df.iloc[:,15:20]
df6 = df.iloc[:,20:24]

#df7 = df.iloc[:,22:24]
#df8 = df.iloc[:,30:33]
#df9 = df.iloc[:,33:36]

df1.plot.bar();
plt.title('Univariate plots, Check Legends for Aspects Plotted')

df2.plot.bar();
df3.plot.bar();
df4.plot.bar();
df5.plot.bar();
df6.plot.bar();
#df7.plot.bar();
#df8.plot.bar();
#df9.plot.bar();

plt.xticks(range(len(df[' Age-group: To USRDS'])), df[' Age-group: From USRDS']);
plt.xlabel('Age Groups (from)')
plt.ylabel('Amount in Gms')
plt.suptitle('Univariate plots, Check Legends for Aspect')

# %%
df1.plot.line();
df2.plot.line();
df3.plot.line();
df4.plot.line();
df5.plot.line();
df6.plot.line();
#df7.plot.line();


plt.xlabel('Age Groups (from)')
plt.ylabel('Amount in Gms')
plt.suptitle('Univariate plots, Check Legends for Aspect')
plt.xticks(range(len(df[' Age-group: To USRDS'])), df[' Age-group: From USRDS']);

# %%
df1.plot.area();
df2.plot.area();
df3.plot.area();
df4.plot.area();
df5.plot.area();
df6.plot.area();
#df7.plot.area();

plt.xlabel('Age Groups (from)')
plt.ylabel('Amount in Gms')
plt.suptitle('Univariate plots, Check Legends for Aspect')
plt.xticks(range(len(df[' Age-group: To USRDS'])), df[' Age-group: From USRDS']);

# %%
df1.plot.hist();
df2.plot.hist();
df3.plot.hist();
df4.plot.hist();
df5.plot.hist();
df6.plot.hist();
#df7.plot.hist();


plt.xlabel('Age Groups (from)')
plt.ylabel('Amount in Gms')
plt.suptitle('Univariate plots, Check Legends for Aspect')
plt.xticks(range(len(df[' Age-group: To USRDS'])), df[' Age-group: From USRDS']);

# %%
df1.plot.box();
df2.plot.box();
df3.plot.box();
df4.plot.box();
df5.plot.box();
df6.plot.box();
#df7.plot.box();


plt.xlabel('Age Groups (from)')
plt.ylabel('Amount in Gms')
plt.suptitle('Univariate plots, Check Legends for Aspect')
plt.xticks(range(len(df[' Age-group: To USRDS'])), df[' Age-group: From USRDS']);

# %%
df.corr()

# %%
import numpy as np
import pandas as pd 
from subprocess import check_output

from IPython.display import display, HTML
from matplotlib import pyplot as plt
import matplotlib.patches as mpatches

import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('./data-for-code/no-empty-cell-mortality_subgroup_data_june_9th_gender_neutral-based_data_after_processing.csv')
df.head()

# %%
df.corr()

# %% [markdown]
# Age-group: From USRDS	Age-group: To USRDS	Actual Dark-green vegetables Intake	Actual Red and orange vegetables Intake	Actual Starchy vegetables Intake	Actual Other vegetables Intake	Actual Whole grains intakes	Actual Taken Refined grains amount	Avg Meat, Poultry and Eggs subgroup taken	Avg Seafood taken	...	Avg Solid Fats taken	Avg Milks and milk drinks taken	Avg Water, noncarbonated intake	Avg Alcoholic beverages intake	Avg Nonalcoholic beverages taken	Avg Milk desserts, sauces, gravies taken	ESRD patients: Total (or %) deaths for target year	ESRD patients: Avg. Annual Mortality rates	Dialysis patients: Total (or %) deaths for target year	Dialysis patients: Avg. Annual Mortality rates
# ESRD patients: Total (or %) deaths for target year	0.909230	0.909458	0.056973	0.572518	0.517307	0.542376	-0.469825	0.112844	-0.036558	0.107024	...	-0.236728	-0.598140	-0.023290	-0.738501	0.384077	0.353425	1.000000	0.833280	0.999627	0.868295
# ESRD patients: Avg. Annual Mortality rates	0.854852	0.854771	-0.082390	0.545127	0.444551	0.676325	-0.609984	0.057939	-0.216943	-0.113325	...	-0.365416	-0.461741	-0.150719	-0.786412	0.192810	0.336838	0.833280	1.000000	0.847302	0.995724
# Dialysis patients: Total (or %) deaths for target year	0.914521	0.914720	0.054157	0.577456	0.518309	0.554746	-0.478563	0.114916	-0.042973	0.100156	...	-0.241894	-0.598720	-0.028184	-0.744098	0.381084	0.357477	0.999627	0.847302	1.000000	0.880661
# Dialysis patients: Avg. Annual Mortality rates	0.878499	0.879277	-0.076082	0.564846	0.453687	0.675571	-0.613042	0.035448	-0.205311	-0.097894	...	-0.369415	-0.485633	-0.136271	-0.791673	0.225472	0.314988	0.868295	0.995724	0.880661	1.000000

# %%
len(df.columns)

# %%
plt.figure(figsize=(12, 8))

corr = df.corr()
sns.heatmap(corr, 
            xticklabels = corr.columns.values,
            yticklabels = corr.columns.values,
            annot = True);

# %%
df = df.drop(['Gender'], axis=1)

# %%
df_normalized = (df - df.mean())/ (df.max() - df.min())
df_normalized.head()

# %%
df_normalized.corr()

# %%
plt.figure(figsize=(12, 8))

corr = df_normalized.corr()
sns.heatmap(corr, 
            xticklabels = corr.columns.values,
            yticklabels = corr.columns.values,
            annot = True);

# %% [markdown]
# # Bivariate
#
# Bivariate plots on actual amount intake and target variables. will be saved in bivariate_food_subgroup.png. The correlation pattern can be checked in the image saved
#
# The correlation are shown in heatmaps and Pearson's correlations. Now linearity and non-linearity can be seen using the Bivariate plots below.
#
# The plots show similarity with correlations

# %%
df = pd.read_csv('./data-for-code/no-empty-cell-mortality_subgroup_data_june_9th_gender_neutral-based_data_after_processing.csv')
df.head()

# %%
df.columns

# %%
# on actual amounts
# plt.figure(figsize=(16, 300))
#df = df.drop(['Gender', 'Age-group: From USRDS', 'Age-group: To USRDS'], axis=1)
sns.pairplot(df, vars=df.columns, size=5, kind='reg'); # diag_kind='kde',
plt.title('Bivariate Plot, Food Subgroups');
plt.savefig('../../progress_reports/to_submit/pca_univariate_bivariate/bivariate_food_subgroup' + '.png')            
plt.show()

# %% [markdown]
# # Bivariate plots with few variables at each plot
#
# 'ESRD patients: Avg. Annual Mortality rates'  is used as the target variable

# %%
df1 = df.iloc[:,3:6]
df1['ESRD patients: Avg. Annual Mortality rates'] = df['ESRD patients: Avg. Annual Mortality rates']


df2 = df.iloc[:,6:9]
df2['ESRD patients: Avg. Annual Mortality rates'] = df['ESRD patients: Avg. Annual Mortality rates']

df3 = df.iloc[:,9:12]
df3['ESRD patients: Avg. Annual Mortality rates'] = df['ESRD patients: Avg. Annual Mortality rates']

df4 = df.iloc[:,12:15]
df4['ESRD patients: Avg. Annual Mortality rates'] = df['ESRD patients: Avg. Annual Mortality rates']


df5 = df.iloc[:,15:17]
df5['ESRD patients: Avg. Annual Mortality rates'] = df['ESRD patients: Avg. Annual Mortality rates']

#df6 = df.iloc[:,18:21]
df7 = df.iloc[:,17:24]
#df7[' ESRD patients: Avg. Annual Mortality rates'] = df[' ESRD patients: Avg. Annual Mortality rates']

# %%
plt.figure(figsize=(14, 14))
sns.pairplot(df1, diag_kind='kde', kind='reg', size=5);

#plt.title('Bivariate Plot, All Actual Taken Variables, Total ESRD target variable')
#plt.yticks(rotation=70);
#plt.xticks(rotation=70);
#g.set_xlabels(g.get_xlabels(), rotation=90)
#plt.xlabel(range(len(df1.columns)), df1.columns, rotation=90);
# plt.setyylable('dd', rotation=90);

# %%
sns.pairplot(df2, diag_kind='kde', kind='reg', size=5);
#plt.title('Bivariate Plot, All Actual Taken Variables, Total ESRD target variable')
#plt.yticks(rotation=90);

# %%
sns.pairplot(df3, diag_kind='kde', kind='reg', size=5);

# %%
sns.pairplot(df4, diag_kind='kde', kind='reg', size=5);

# %%
sns.pairplot(df5, diag_kind='kde', kind='reg', size=5);
#plt.title('Bivariate Plot, All Actual Taken Variables, Total ESRD target variable')
#plt.yticks(rotation=90);

# %%
sns.pairplot(df6, diag_kind='kde', kind='reg', size=5);
#plt.title('Bivariate Plot, All Actual Taken Variables, Total ESRD target variable')
#plt.yticks(rotation=90);

# %% [markdown]
# # PCA: Just experiment and Exploration only:
# # Will reuse some methods from a github project and apply on our data

# %%
#steps followed from ref: https://python-for-multivariate-analysis.readthedocs.io/a_little_book_of_python_for_multivariate_analysis.html
df = pd.read_csv('./data-for-code/no-empty-cell-mortality_subgroup_data_june_9th_gender_neutral-based_data_after_processing.csv')
df.head()

# %%
df_pca = df.drop(['Age-group: From USRDS', 'Age-group: To USRDS', 'Gender'],axis=1)
import sklearn 
from sklearn import preprocessing
import numpy as np
standardisedX = sklearn.preprocessing.scale(df_pca)
standardisedX = pd.DataFrame(standardisedX, index=df_pca.index, columns=df_pca.columns)
standardisedX.apply(np.mean)

# %%
standardisedX.apply(np.std)

# %%
from sklearn import decomposition
pca = decomposition.PCA().fit(standardisedX)
pca

# %%
#ref: https://python-for-multivariate-analysis.readthedocs.io/a_little_book_of_python_for_multivariate_analysis.html
def pca_summary(pca, standardised_data, out=True):
    names = ["PC"+str(i) for i in range(1, len(pca.explained_variance_ratio_)+1)]
    a = list(np.std(pca.transform(standardised_data), axis=0))
    b = list(pca.explained_variance_ratio_)
    c = [np.sum(pca.explained_variance_ratio_[:i]) for i in range(1, len(pca.explained_variance_ratio_)+1)]
    columns = pd.MultiIndex.from_tuples([("sdev", "Standard deviation"), ("varprop", "Proportion of Variance"), ("cumprop", "Cumulative Proportion")])
    summary = pd.DataFrame( list(zip(a, b, c)), index=names, columns=columns)
    if out:
        print("Importance of components:")
        display(summary)
    return summary

# %%
summary = pca_summary(pca, standardisedX)

# %%
# First Five component can define over 91%

# %%
np.sum(summary.sdev**2)

# %%
# ref: https://python-for-multivariate-analysis.readthedocs.io/a_little_book_of_python_for_multivariate_analysis.html
def screeplot(pca, standardised_values):
    y = np.std(pca.transform(standardised_values), axis=0)**2
    x = np.arange(len(y)) + 1
    plt.plot(x, y, "o-")
    plt.xticks(x, ["Comp."+str(i) for i in x], rotation=60)
    plt.ylabel("Variance")
    plt.show()

plt.rcParams['figure.figsize'] = 8, 8   
screeplot(pca, standardisedX)

# %%
# comp 3 to comp 4 is the most change for slope
# first three or at best first 4 can be retained

# %%
summary.sdev**2

# %%
pca.components_[0]

# %%
np.sum(pca.components_[0]**2)

# %%
# ref: https://python-for-multivariate-analysis.readthedocs.io/a_little_book_of_python_for_multivariate_analysis.html
# not my code, I am using this as (similar to) a library function
def calcpc(variables, loadings):
    # find the number of samples in the data set and the number of variables
    numsamples, numvariables = variables.shape
    # make a vector to store the component
    pc = np.zeros(numsamples)
    # calculate the value of the component for each sample
    for i in range(numsamples):
        valuei = 0
        for j in range(numvariables):
            valueij = variables.iloc[i, j]
            loadingj = loadings[j]
            valuei = valuei + (valueij * loadingj)
        pc[i] = valuei
    return pc

# %%
calcpc(standardisedX, pca.components_[0])

# %%
pca.transform(standardisedX)[:, 0]

# %%
pca.components_[1]

# %%
np.sum(pca.components_[1]**2)

# %%
# for following code : Classes will/might be defined such as like High, low, neutral mortality in final work

# %%
sorted(standardisedX['ESRD patients: Avg. Annual Mortality rates'])

# %%
y = standardisedX['ESRD patients: Avg. Annual Mortality rates'] > 0.5
y

# %%
# # ref: https://python-for-multivariate-analysis.readthedocs.io/a_little_book_of_python_for_multivariate_analysis.html
# not my code from the URL above, using this as a library function
def pca_scatter(pca, standardised_values, classifs):
    foo = pca.transform(standardised_values)
    bar = pd.DataFrame(list(zip(foo[:, 0], foo[:, 1], classifs)), columns=["PC1", "PC2", "Class"])
    sns.lmplot("PC1", "PC2", bar, hue="Class", fit_reg=False)

#y = df_pca[' ESRD patients: Total (or %) deaths for target year']
#y = np.std(pca.transform(standardisedX), axis=0)**2
pca_scatter(pca, standardisedX, y)

# y can be used as classes like High, low, neutral mortality

plt.suptitle('Mortality class and Principle components, y can be used as classes like High, low, neutral mortality');

# %%
# reference: https://towardsdatascience.com/dive-into-pca-principal-component-analysis-with-python-43ded13ead21



#keep four components
pca_components_cont = pca.components_[0:5]

plt.matshow(pca_components_cont, cmap='viridis')
plt.yticks([0,1,2,3],['1st Comp','2nd Comp', '3rd comp', '4th comp'],fontsize=10)
plt.colorbar()

plt.xticks(range(len(df_pca.columns)), df_pca.columns, rotation=65,ha='left')

plt.savefig('../../progress_reports/to_submit/pca_univariate_bivariate/pca_food_sub_groups_what_contributes_to_PCA_components' + '.png')            
plt.show()#

# %%
plt.figure(figsize=(16, 10));

diffs = list(df_pca.columns[:-1]) 
import seaborn as sns
s = sns.heatmap(df_pca[diffs].corr(),cmap='coolwarm') 
#s.set_yticklabels(s.get_yticklabels(),rotation=60,fontsize=7)
s.set_xticklabels(s.get_xticklabels(),rotation=90,fontsize=7)
plt.savefig('../../progress_reports/to_submit/pca_univariate_bivariate/pca_food_sub_groups_how_in_together_influencing_PCA_components' + '.png')            
plt.show()

# %% [markdown]
# https://www.kaggle.com/etakla/exploring-the-dataset-univariate-analysis
# https://www.kaggle.com/etakla/exploring-the-dataset-bivariate-analysis
# https://towardsdatascience.com/survival-analysis-part-a-70213df21c2e
# https://lifelines.readthedocs.io/en/latest/
# https://lifelines.readthedocs.io/en/latest/Survival%20Regression.html
# https://www.statsdirect.com/help/survival_analysis/cox_regression.htm
# https://courses.lumenlearning.com/suny-natural-resources-biometrics/chapter/chapter-7-correlation-and-simple-linear-regression/

# %% [markdown]
# # References
# https://scikit-learn.org/stable/auto_examples/linear_model/plot_ols.html
#
# https://www.shanelynn.ie/using-pandas-dataframe-creating-editing-viewing-data-in-python/
#
# https://python-for-multivariate-analysis.readthedocs.io/a_little_book_of_python_for_multivariate_analysis.html
